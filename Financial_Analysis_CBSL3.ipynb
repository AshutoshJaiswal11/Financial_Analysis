# %% [markdown]
# <a href="https://colab.research.google.com/github/AshutoshJaiswal11/Financial_Analysis/blob/main/Financial_Analysis_CBSL3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Analysis of Financial Statements: XYZ Bank<center>

# %%
# @title

# Import the necessary libraries

import os
import pandas as pd
import matplotlib.pyplot as plt
import cufflinks as cf
import numpy as np


import missingno
import datetime as dt

import warnings
warnings.filterwarnings('ignore')
import plotly.express
import time

# %%
# @title
os.getcwd()
# Out:
# '/content'

# %%
# @title

url = 'https://github.com/AshutoshJaiswal11/Financial_Analysis/raw/main/Financial_Template_2026_1.xlsx'
df1 = pd.read_excel(url,sheet_name = "BS", index_col=0, parse_dates=True)
df1.head()  # Preview first 5 rows
# Out:
#                        2013-03-31  2014-03-31  2015-03-31  2016-03-31  \
# ITEMS
# Paid up share capital       14.57     14.8400     15.6400      15.830
# Reserve Fund                88.20     92.5700     95.9400     100.250
# Other Reserve                0.00      0.0000      0.0000       0.000
# Deposits                   565.15    642.5600    746.9800     872.880
# Borrowings                  61.23    119.6625     69.5125      26.845
#
#                        2017-03-31  2018-03-31  2019-03-31  2020-03-31  \
# ITEMS
# Paid up share capital     15.2200       15.38       16.13      18.350
# Reserve Fund             104.7400      111.22      118.13     128.600
# Other Reserve              0.0000        0.00        0.00       0.000
# Deposits                1039.1800     1142.61     1355.43    1366.590
# Borrowings                 1.9475        1.30       11.08      12.065
#
#                        2021-03-31  2022-03-31  2023-03-31  2024-03-31  \
# ITEMS
# Paid up share capital      20.150       21.43       23.39       24.74
# Reserve Fund              139.950      202.13      216.46      222.17
# Other Reserve               0.000        0.00        0.00        0.00
# Deposits                 1498.510     1663.26     1967.72     2071.38
# Borrowings                 14.265       14.03       17.99       15.62
#
#                        2025-03-31  2026-03-31
# ITEMS
# Paid up share capital       24.41       23.94
# Reserve Fund               262.25      263.76
# Other Reserve                0.00        0.00
# Deposits                  2206.13     2530.66
# Borrowings                  12.11       11.23

# %%
df1
# Out:
#                                    2013-03-31  2014-03-31  2015-03-31  \
# ITEMS
# Paid up share capital                   14.57     14.8400     15.6400
# Reserve Fund                            88.20     92.5700     95.9400
# Other Reserve                            0.00      0.0000      0.0000
# Deposits                               565.15    642.5600    746.9800
# Borrowings                              61.23    119.6625     69.5125
# Interest Payable                         0.59      0.7200      0.9100
# Other Liabilities                       11.06     13.9100     16.7000
# Profit or (Loss)                         4.52      4.6700      5.6700
# Current Tax Liabilities                  1.13      1.1675      1.4175
# Cash + Balance with CBSL                36.61     36.9900     36.6700
# Balances with other Banks               10.50      6.0200      9.1800
# Balances with other Banks as FDR        76.21     84.8300    113.8500
# Securities bought under repo             0.00      0.0000      0.0000
# Investments (Amortised cost)           279.64    361.0000    326.1500
# Loans & Advances (Amortised cost)      314.78    367.3900    424.9800
# Interest Receivable                      7.42      9.8500      9.6900
# Bills Purchased & Discounted             1.81      0.5700      0.6100
# Fixed Assets                             7.08      9.4600      9.0300
# Investment in properties                 0.00      0.0000      0.0000
# Other Assets                            12.40     13.9900     22.6100
# Total Assets                           746.45    890.1000    952.7700
#
#                                    2016-03-31  2017-03-31  2018-03-31  \
# ITEMS
# Paid up share capital                  15.830     15.2200       15.38
# Reserve Fund                          100.250    104.7400      111.22
# Other Reserve                           0.000      0.0000        0.00
# Deposits                              872.880   1039.1800     1142.61
# Borrowings                             26.845      1.9475        1.30
# Interest Payable                        0.890      0.8800        1.09
# Other Liabilities                      20.660     20.0300       24.26
# Profit or (Loss)                        5.940      7.8500        7.20
# Current Tax Liabilities                 1.485      1.9625        1.80
# Cash + Balance with CBSL               42.400     61.3400       57.21
# Balances with other Banks               5.680     10.1900        9.71
# Balances with other Banks as FDR       94.160    150.9700      180.51
# Securities bought under repo            0.000     24.9600       29.97
# Investments (Amortised cost)          343.940    304.6600      293.19
# Loans & Advances (Amortised cost)     508.230    589.4500      678.16
# Interest Receivable                     9.900     13.4700       11.18
# Bills Purchased & Discounted            3.100      3.6200        3.02
# Fixed Assets                           12.820     15.1100       21.39
# Investment in properties                0.000      0.0000        0.00
# Other Assets                           24.550     18.0400       20.52
# Total Assets                         1044.780   1191.8100     1304.86
#
#                                    2019-03-31  2020-03-31  2021-03-31  \
# ITEMS
# Paid up share capital                   16.13     18.3500     20.1500
# Reserve Fund                           118.13    128.6000    139.9500
# Other Reserve                            0.00      0.0000      0.0000
# Deposits                              1355.43   1366.5900   1498.5100
# Borrowings                              11.08     12.0650     14.2650
# Interest Payable                         1.21      1.1900      0.2100
# Other Liabilities                       22.49     25.6900     29.6200
# Profit or (Loss)                         9.96     10.2500     12.0300
# Current Tax Liabilities                  2.49      2.5625      3.0075
# Cash + Balance with CBSL                60.36     78.0800     93.6000
# Balances with other Banks               14.84     20.7300      9.3200
# Balances with other Banks as FDR       190.08    114.5400     98.8100
# Securities bought under repo           125.00     12.1575     15.9225
# Investments (Amortised cost)           351.76    379.9900    434.1400
# Loans & Advances (Amortised cost)      728.48    901.4700   1007.8700
# Interest Receivable                     13.67     12.2300     10.2100
# Bills Purchased & Discounted            13.51      2.3900      1.3800
# Fixed Assets                            19.44     18.0400     20.7900
# Investment in properties                 0.00      0.0000      0.0000
# Other Assets                            19.78     25.6700     25.7000
# Total Assets                          1536.92   1565.2975   1717.7425
#
#                                    2022-03-31  2023-03-31  2024-03-31  \
# ITEMS
# Paid up share capital                  21.430      23.390       24.74
# Reserve Fund                          202.130     216.460      222.17
# Other Reserve                           0.000       0.000        0.00
# Deposits                             1663.260    1967.720     2071.38
# Borrowings                             14.030      17.990       15.62
# Interest Payable                        0.300       0.240        0.24
# Other Liabilities                      29.320       9.660       23.39
# Profit or (Loss)                       14.340      12.420       12.80
# Current Tax Liabilities                 3.585       3.105        3.20
# Cash + Balance with CBSL              176.240      92.960      195.27
# Balances with other Banks              11.680      12.320       28.58
# Balances with other Banks as FDR      151.460     153.160       97.08
# Securities bought under repo           15.515      19.935       17.20
# Investments (Amortised cost)          429.450     727.410      804.90
# Loans & Advances (Amortised cost)    1041.140    1043.920     1128.73
# Interest Receivable                    13.990      20.000       17.29
# Bills Purchased & Discounted            2.110       1.440        1.65
# Fixed Assets                           80.430      75.050       69.48
# Investment in properties                0.000       0.000        0.00
# Other Assets                           26.380     104.790       13.36
# Total Assets                         1948.395    2250.985     2373.54
#
#                                    2025-03-31  2026-03-31
# ITEMS
# Paid up share capital                  24.410      23.940
# Reserve Fund                          262.250     263.760
# Other Reserve                           0.000       0.000
# Deposits                             2206.130    2530.660
# Borrowings                             12.110      11.230
# Interest Payable                        0.250       0.180
# Other Liabilities                      40.270      17.030
# Profit or (Loss)                       13.540      18.420
# Current Tax Liabilities                 3.385       4.605
# Cash + Balance with CBSL              157.020     229.280
# Balances with other Banks              29.380      23.790
# Balances with other Banks as FDR       87.750     182.700
# Securities bought under repo           15.345      13.635
# Investments (Amortised cost)          786.710     788.870
# Loans & Advances (Amortised cost)    1327.590    1513.360
# Interest Receivable                    16.060      20.650
# Bills Purchased & Discounted            0.300       2.550
# Fixed Assets                           95.940      89.810
# Investment in properties                0.000       0.000
# Other Assets                           46.250       5.180
# Total Assets                         2562.345    2869.825

# %%
# @title
df2=pd.DataFrame(df1)
print(f'Latest available Financial Year data: {str(df2.columns[-1].date())}')

# Extracting FY as column names

df2.columns = [df2.columns[i].date() for i in range(len(df2.columns))]
# Out:
# Latest available Financial Year data: 2026-03-31

# %%
df2
# Out:
#                                    2013-03-31  2014-03-31  2015-03-31  \
# ITEMS
# Paid up share capital                   14.57     14.8400     15.6400
# Reserve Fund                            88.20     92.5700     95.9400
# Other Reserve                            0.00      0.0000      0.0000
# Deposits                               565.15    642.5600    746.9800
# Borrowings                              61.23    119.6625     69.5125
# Interest Payable                         0.59      0.7200      0.9100
# Other Liabilities                       11.06     13.9100     16.7000
# Profit or (Loss)                         4.52      4.6700      5.6700
# Current Tax Liabilities                  1.13      1.1675      1.4175
# Cash + Balance with CBSL                36.61     36.9900     36.6700
# Balances with other Banks               10.50      6.0200      9.1800
# Balances with other Banks as FDR        76.21     84.8300    113.8500
# Securities bought under repo             0.00      0.0000      0.0000
# Investments (Amortised cost)           279.64    361.0000    326.1500
# Loans & Advances (Amortised cost)      314.78    367.3900    424.9800
# Interest Receivable                      7.42      9.8500      9.6900
# Bills Purchased & Discounted             1.81      0.5700      0.6100
# Fixed Assets                             7.08      9.4600      9.0300
# Investment in properties                 0.00      0.0000      0.0000
# Other Assets                            12.40     13.9900     22.6100
# Total Assets                           746.45    890.1000    952.7700
#
#                                    2016-03-31  2017-03-31  2018-03-31  \
# ITEMS
# Paid up share capital                  15.830     15.2200       15.38
# Reserve Fund                          100.250    104.7400      111.22
# Other Reserve                           0.000      0.0000        0.00
# Deposits                              872.880   1039.1800     1142.61
# Borrowings                             26.845      1.9475        1.30
# Interest Payable                        0.890      0.8800        1.09
# Other Liabilities                      20.660     20.0300       24.26
# Profit or (Loss)                        5.940      7.8500        7.20
# Current Tax Liabilities                 1.485      1.9625        1.80
# Cash + Balance with CBSL               42.400     61.3400       57.21
# Balances with other Banks               5.680     10.1900        9.71
# Balances with other Banks as FDR       94.160    150.9700      180.51
# Securities bought under repo            0.000     24.9600       29.97
# Investments (Amortised cost)          343.940    304.6600      293.19
# Loans & Advances (Amortised cost)     508.230    589.4500      678.16
# Interest Receivable                     9.900     13.4700       11.18
# Bills Purchased & Discounted            3.100      3.6200        3.02
# Fixed Assets                           12.820     15.1100       21.39
# Investment in properties                0.000      0.0000        0.00
# Other Assets                           24.550     18.0400       20.52
# Total Assets                         1044.780   1191.8100     1304.86
#
#                                    2019-03-31  2020-03-31  2021-03-31  \
# ITEMS
# Paid up share capital                   16.13     18.3500     20.1500
# Reserve Fund                           118.13    128.6000    139.9500
# Other Reserve                            0.00      0.0000      0.0000
# Deposits                              1355.43   1366.5900   1498.5100
# Borrowings                              11.08     12.0650     14.2650
# Interest Payable                         1.21      1.1900      0.2100
# Other Liabilities                       22.49     25.6900     29.6200
# Profit or (Loss)                         9.96     10.2500     12.0300
# Current Tax Liabilities                  2.49      2.5625      3.0075
# Cash + Balance with CBSL                60.36     78.0800     93.6000
# Balances with other Banks               14.84     20.7300      9.3200
# Balances with other Banks as FDR       190.08    114.5400     98.8100
# Securities bought under repo           125.00     12.1575     15.9225
# Investments (Amortised cost)           351.76    379.9900    434.1400
# Loans & Advances (Amortised cost)      728.48    901.4700   1007.8700
# Interest Receivable                     13.67     12.2300     10.2100
# Bills Purchased & Discounted            13.51      2.3900      1.3800
# Fixed Assets                            19.44     18.0400     20.7900
# Investment in properties                 0.00      0.0000      0.0000
# Other Assets                            19.78     25.6700     25.7000
# Total Assets                          1536.92   1565.2975   1717.7425
#
#                                    2022-03-31  2023-03-31  2024-03-31  \
# ITEMS
# Paid up share capital                  21.430      23.390       24.74
# Reserve Fund                          202.130     216.460      222.17
# Other Reserve                           0.000       0.000        0.00
# Deposits                             1663.260    1967.720     2071.38
# Borrowings                             14.030      17.990       15.62
# Interest Payable                        0.300       0.240        0.24
# Other Liabilities                      29.320       9.660       23.39
# Profit or (Loss)                       14.340      12.420       12.80
# Current Tax Liabilities                 3.585       3.105        3.20
# Cash + Balance with CBSL              176.240      92.960      195.27
# Balances with other Banks              11.680      12.320       28.58
# Balances with other Banks as FDR      151.460     153.160       97.08
# Securities bought under repo           15.515      19.935       17.20
# Investments (Amortised cost)          429.450     727.410      804.90
# Loans & Advances (Amortised cost)    1041.140    1043.920     1128.73
# Interest Receivable                    13.990      20.000       17.29
# Bills Purchased & Discounted            2.110       1.440        1.65
# Fixed Assets                           80.430      75.050       69.48
# Investment in properties                0.000       0.000        0.00
# Other Assets                           26.380     104.790       13.36
# Total Assets                         1948.395    2250.985     2373.54
#
#                                    2025-03-31  2026-03-31
# ITEMS
# Paid up share capital                  24.410      23.940
# Reserve Fund                          262.250     263.760
# Other Reserve                           0.000       0.000
# Deposits                             2206.130    2530.660
# Borrowings                             12.110      11.230
# Interest Payable                        0.250       0.180
# Other Liabilities                      40.270      17.030
# Profit or (Loss)                       13.540      18.420
# Current Tax Liabilities                 3.385       4.605
# Cash + Balance with CBSL              157.020     229.280
# Balances with other Banks              29.380      23.790
# Balances with other Banks as FDR       87.750     182.700
# Securities bought under repo           15.345      13.635
# Investments (Amortised cost)          786.710     788.870
# Loans & Advances (Amortised cost)    1327.590    1513.360
# Interest Receivable                    16.060      20.650
# Bills Purchased & Discounted            0.300       2.550
# Fixed Assets                           95.940      89.810
# Investment in properties                0.000       0.000
# Other Assets                           46.250       5.180
# Total Assets                         2562.345    2869.825

# %% [markdown]
# # 1. Financial Perfromance Analysis
#
# We are looking at time series data and examining YoY change for lastest FY data

# %%
# @title

# Computing % change in last FY BS items over previous year

df2.fillna(0)
df2['% change'] = np.round((np.divide(np.array(df2.iloc[:,-1:]), np.array(df2.iloc[:,-2:-1]))-1)*100,2)
df2.fillna(0, inplace = True)

# %%
# @title

# Plotting change in all BS items

fig = plt.figure(figsize=(20, 10))

c = ['red', 'blue', 'magenta', 'orange', 'brown', 'green', 'cyan']

bars = plt.bar(df2.index[np.abs(df2['% change']!=0)], df2['% change'][np.abs(df2['% change']!=0)], color=c)

# Add value labels
plt.bar_label(bars, fmt='%.1f%%', padding=5, fontsize=13)

plt.xticks(rotation=90, fontsize=15)
plt.axhline(-20, linestyle='dashed')
plt.axhline(20, linestyle='dashed')

plt.xlabel('Balance Sheet Item', fontsize=20)
plt.ylabel('% change over prev year', fontsize=20)
plt.title(f'Movement of Balance Sheet Items as on {df2.columns[-2]}', fontsize=20)
plt.show()

# %%
# @title
# re-frame the data file for further processing

df2.drop(['% change'], axis = 1, inplace= True)
col_ind = [df2.columns[i] for i in range(len(df2.columns))]
df2
# Out:
#                                    2013-03-31  2014-03-31  2015-03-31  \
# ITEMS
# Paid up share capital                   14.57     14.8400     15.6400
# Reserve Fund                            88.20     92.5700     95.9400
# Other Reserve                            0.00      0.0000      0.0000
# Deposits                               565.15    642.5600    746.9800
# Borrowings                              61.23    119.6625     69.5125
# Interest Payable                         0.59      0.7200      0.9100
# Other Liabilities                       11.06     13.9100     16.7000
# Profit or (Loss)                         4.52      4.6700      5.6700
# Current Tax Liabilities                  1.13      1.1675      1.4175
# Cash + Balance with CBSL                36.61     36.9900     36.6700
# Balances with other Banks               10.50      6.0200      9.1800
# Balances with other Banks as FDR        76.21     84.8300    113.8500
# Securities bought under repo             0.00      0.0000      0.0000
# Investments (Amortised cost)           279.64    361.0000    326.1500
# Loans & Advances (Amortised cost)      314.78    367.3900    424.9800
# Interest Receivable                      7.42      9.8500      9.6900
# Bills Purchased & Discounted             1.81      0.5700      0.6100
# Fixed Assets                             7.08      9.4600      9.0300
# Investment in properties                 0.00      0.0000      0.0000
# Other Assets                            12.40     13.9900     22.6100
# Total Assets                           746.45    890.1000    952.7700
#
#                                    2016-03-31  2017-03-31  2018-03-31  \
# ITEMS
# Paid up share capital                  15.830     15.2200       15.38
# Reserve Fund                          100.250    104.7400      111.22
# Other Reserve                           0.000      0.0000        0.00
# Deposits                              872.880   1039.1800     1142.61
# Borrowings                             26.845      1.9475        1.30
# Interest Payable                        0.890      0.8800        1.09
# Other Liabilities                      20.660     20.0300       24.26
# Profit or (Loss)                        5.940      7.8500        7.20
# Current Tax Liabilities                 1.485      1.9625        1.80
# Cash + Balance with CBSL               42.400     61.3400       57.21
# Balances with other Banks               5.680     10.1900        9.71
# Balances with other Banks as FDR       94.160    150.9700      180.51
# Securities bought under repo            0.000     24.9600       29.97
# Investments (Amortised cost)          343.940    304.6600      293.19
# Loans & Advances (Amortised cost)     508.230    589.4500      678.16
# Interest Receivable                     9.900     13.4700       11.18
# Bills Purchased & Discounted            3.100      3.6200        3.02
# Fixed Assets                           12.820     15.1100       21.39
# Investment in properties                0.000      0.0000        0.00
# Other Assets                           24.550     18.0400       20.52
# Total Assets                         1044.780   1191.8100     1304.86
#
#                                    2019-03-31  2020-03-31  2021-03-31  \
# ITEMS
# Paid up share capital                   16.13     18.3500     20.1500
# Reserve Fund                           118.13    128.6000    139.9500
# Other Reserve                            0.00      0.0000      0.0000
# Deposits                              1355.43   1366.5900   1498.5100
# Borrowings                              11.08     12.0650     14.2650
# Interest Payable                         1.21      1.1900      0.2100
# Other Liabilities                       22.49     25.6900     29.6200
# Profit or (Loss)                         9.96     10.2500     12.0300
# Current Tax Liabilities                  2.49      2.5625      3.0075
# Cash + Balance with CBSL                60.36     78.0800     93.6000
# Balances with other Banks               14.84     20.7300      9.3200
# Balances with other Banks as FDR       190.08    114.5400     98.8100
# Securities bought under repo           125.00     12.1575     15.9225
# Investments (Amortised cost)           351.76    379.9900    434.1400
# Loans & Advances (Amortised cost)      728.48    901.4700   1007.8700
# Interest Receivable                     13.67     12.2300     10.2100
# Bills Purchased & Discounted            13.51      2.3900      1.3800
# Fixed Assets                            19.44     18.0400     20.7900
# Investment in properties                 0.00      0.0000      0.0000
# Other Assets                            19.78     25.6700     25.7000
# Total Assets                          1536.92   1565.2975   1717.7425
#
#                                    2022-03-31  2023-03-31  2024-03-31  \
# ITEMS
# Paid up share capital                  21.430      23.390       24.74
# Reserve Fund                          202.130     216.460      222.17
# Other Reserve                           0.000       0.000        0.00
# Deposits                             1663.260    1967.720     2071.38
# Borrowings                             14.030      17.990       15.62
# Interest Payable                        0.300       0.240        0.24
# Other Liabilities                      29.320       9.660       23.39
# Profit or (Loss)                       14.340      12.420       12.80
# Current Tax Liabilities                 3.585       3.105        3.20
# Cash + Balance with CBSL              176.240      92.960      195.27
# Balances with other Banks              11.680      12.320       28.58
# Balances with other Banks as FDR      151.460     153.160       97.08
# Securities bought under repo           15.515      19.935       17.20
# Investments (Amortised cost)          429.450     727.410      804.90
# Loans & Advances (Amortised cost)    1041.140    1043.920     1128.73
# Interest Receivable                    13.990      20.000       17.29
# Bills Purchased & Discounted            2.110       1.440        1.65
# Fixed Assets                           80.430      75.050       69.48
# Investment in properties                0.000       0.000        0.00
# Other Assets                           26.380     104.790       13.36
# Total Assets                         1948.395    2250.985     2373.54
#
#                                    2025-03-31  2026-03-31
# ITEMS
# Paid up share capital                  24.410      23.940
# Reserve Fund                          262.250     263.760
# Other Reserve                           0.000       0.000
# Deposits                             2206.130    2530.660
# Borrowings                             12.110      11.230
# Interest Payable                        0.250       0.180
# Other Liabilities                      40.270      17.030
# Profit or (Loss)                       13.540      18.420
# Current Tax Liabilities                 3.385       4.605
# Cash + Balance with CBSL              157.020     229.280
# Balances with other Banks              29.380      23.790
# Balances with other Banks as FDR       87.750     182.700
# Securities bought under repo           15.345      13.635
# Investments (Amortised cost)          786.710     788.870
# Loans & Advances (Amortised cost)    1327.590    1513.360
# Interest Receivable                    16.060      20.650
# Bills Purchased & Discounted            0.300       2.550
# Fixed Assets                           95.940      89.810
# Investment in properties                0.000       0.000
# Other Assets                           46.250       5.180
# Total Assets                         2562.345    2869.825

# %% [markdown]
# ### 1.1 Visualizing Financial Parameters of Interest

# %%
# plotting the timeseries plot of balance sheet items over the years

fig=plt.figure(figsize=(30,35))
#fig.tight_layout(h_pad= 0.5, w_pad= .5)

items = round(len(df2.index)/4)

for i in range(1,len(df2.index)):
    plt.subplot(items, 4, i)
    plt.plot(df2.columns,df2.iloc[i-1])
    plt.xticks(fontsize=15)
    plt.title(f'{df2.index[i-1]}', fontsize=20)

plt.suptitle('Trend in Key Financials',fontsize = 30, y = 1.01)
plt.tight_layout(h_pad=0.5, w_pad=0.5, rect=[0, 0, 1, 1])
plt.show()

# %% [markdown]
# # 2. Earnings Analysis
#
# Here we disect the components of Return on Capital Employed (ROCE) into various sub-components to gain insight into sources and quality of earnings. A typical company's P&L can be viewed as consisting of following items:
#
# Sales
#
# -COGS
# ________________
# **Gross Profit**
#
# -SG&A
# ___________________
# **Operating Profit**
#
# -Depreciation & Provisions
#
# __________________________
# **EBIT**
#
# -Interest paid
# ____________________________
# **EBT**
#
# -Taxes
# _________________________
# **Net Income**
#
#
#
#
# However, in case of banks, Interest paid is treated as COGS since that is the cost paid by banks to generate sales i.e., earn income on its assets.
#
# and ROCE may be expressed as:

# %% [markdown]
# $$ROCE=\frac{PBT} {Average\ Capital}$$

# %% [markdown]
# For a bank, we make the following adjustments:
#
# **Total Income** = Interest Income + Other Income
#
# **PBT** = Interest Income + Other Income - Interest Expense - Total Operating Exp - Provisions
#
# **Average Capital** = (Opening Capital + Closing Capital)/2
#
# **Average Total Assets** = (Opening Total Assets + Closing Total Assets)/2
#
# And, we break the ROCE in sub-components to analyze the bank's income drivers:

# %% [markdown]
# $$ROCE= \frac {PBT} {Tot Income} \ X \  \frac {Tot Income} {Average\ Total\ Assets}  \ X \  \frac {Average\ Total\ Assets} {Average \ Capital}$$

# %%
# @title
# Reading the p&L data

df7=pd.read_excel(url,sheet_name='P&L',index_col=0, parse_dates=True)
df7.fillna(0)
df7['% change'] = np.round((np.divide(np.array(df7.iloc[:,-1:]), np.array(df7.iloc[:,-2:-1]))-1)*100,2)

# %%
df7
# Out:
#                                                  2013-03-31 00:00:00  \
# Income
# Interest & Discount                                            54.23
# Other receipts (including non-operating income)                 6.31
# Total Income                                                   60.54
# Interest paid                                                  31.58
# Operating Expenses                                             14.58
# Other Operating expenses                                        2.42
# Total operating expenses                                       17.00
# Operating Profit before provisions & taxes                     11.96
# Provision against risks/ contingencies                          7.44
# Profit before tax                                               4.52
#
#                                                  2014-03-31 00:00:00  \
# Income
# Interest & Discount                                            67.48
# Other receipts (including non-operating income)                 8.82
# Total Income                                                   76.30
# Interest paid                                                  45.40
# Operating Expenses                                             15.81
# Other Operating expenses                                        2.53
# Total operating expenses                                       18.34
# Operating Profit before provisions & taxes                     12.56
# Provision against risks/ contingencies                          7.89
# Profit before tax                                               4.67
#
#                                                  2015-03-31 00:00:00  \
# Income
# Interest & Discount                                            77.76
# Other receipts (including non-operating income)                13.83
# Total Income                                                   91.59
# Interest paid                                                  54.19
# Operating Expenses                                             18.71
# Other Operating expenses                                        2.69
# Total operating expenses                                       21.40
# Operating Profit before provisions & taxes                     16.00
# Provision against risks/ contingencies                         10.33
# Profit before tax                                               5.67
#
#                                                  2016-03-31 00:00:00  \
# Income
# Interest & Discount                                            88.37
# Other receipts (including non-operating income)                13.02
# Total Income                                                  101.39
# Interest paid                                                  62.62
# Operating Expenses                                             21.19
# Other Operating expenses                                        2.79
# Total operating expenses                                       23.98
# Operating Profit before provisions & taxes                     14.79
# Provision against risks/ contingencies                          8.85
# Profit before tax                                               5.94
#
#                                                  2017-03-31 00:00:00  \
# Income
# Interest & Discount                                           100.76
# Other receipts (including non-operating income)                15.37
# Total Income                                                  116.13
# Interest paid                                                  71.07
# Operating Expenses                                             22.33
# Other Operating expenses                                        3.38
# Total operating expenses                                       25.71
# Operating Profit before provisions & taxes                     19.35
# Provision against risks/ contingencies                         11.50
# Profit before tax                                               7.85
#
#                                                  2018-03-31 00:00:00  \
# Income
# Interest & Discount                                           108.14
# Other receipts (including non-operating income)                12.24
# Total Income                                                  120.38
# Interest paid                                                  76.32
# Operating Expenses                                             23.52
# Other Operating expenses                                        5.02
# Total operating expenses                                       28.54
# Operating Profit before provisions & taxes                     15.52
# Provision against risks/ contingencies                          8.32
# Profit before tax                                               7.20
#
#                                                  2019-03-31 00:00:00  \
# Income
# Interest & Discount                                           115.65
# Other receipts (including non-operating income)                12.55
# Total Income                                                  128.20
# Interest paid                                                  82.74
# Operating Expenses                                             24.08
# Other Operating expenses                                        5.64
# Total operating expenses                                       29.72
# Operating Profit before provisions & taxes                     15.74
# Provision against risks/ contingencies                          5.78
# Profit before tax                                               9.96
#
#                                                  2020-03-31 00:00:00  \
# Income
# Interest & Discount                                           120.20
# Other receipts (including non-operating income)                19.00
# Total Income                                                  139.20
# Interest paid                                                  82.44
# Operating Expenses                                             27.14
# Other Operating expenses                                        7.40
# Total operating expenses                                       34.54
# Operating Profit before provisions & taxes                     22.22
# Provision against risks/ contingencies                         11.97
# Profit before tax                                              10.25
#
#                                                  2021-03-31 00:00:00  \
# Income
# Interest & Discount                                           128.60
# Other receipts (including non-operating income)                16.43
# Total Income                                                  145.03
# Interest paid                                                  86.51
# Operating Expenses                                             28.76
# Other Operating expenses                                        5.64
# Total operating expenses                                       34.40
# Operating Profit before provisions & taxes                     24.12
# Provision against risks/ contingencies                         12.09
# Profit before tax                                              12.03
#
#                                                  2022-03-31 00:00:00  \
# Income
# Interest & Discount                                           140.03
# Other receipts (including non-operating income)                22.13
# Total Income                                                  162.16
# Interest paid                                                 101.85
# Operating Expenses                                             29.84
# Other Operating expenses                                        6.41
# Total operating expenses                                       36.25
# Operating Profit before provisions & taxes                     24.06
# Provision against risks/ contingencies                          9.72
# Profit before tax                                              14.34
#
#                                                  2023-03-31 00:00:00  \
# Income
# Interest & Discount                                           139.94
# Other receipts (including non-operating income)                31.44
# Total Income                                                  171.38
# Interest paid                                                 108.52
# Operating Expenses                                             34.53
# Other Operating expenses                                        6.65
# Total operating expenses                                       41.18
# Operating Profit before provisions & taxes                     21.68
# Provision against risks/ contingencies                          9.26
# Profit before tax                                              12.42
#
#                                                  2024-03-31 00:00:00  \
# Income
# Interest & Discount                                           144.11
# Other receipts (including non-operating income)                27.80
# Total Income                                                  171.91
# Interest paid                                                 104.68
# Operating Expenses                                             33.90
# Other Operating expenses                                       12.67
# Total operating expenses                                       46.57
# Operating Profit before provisions & taxes                     20.66
# Provision against risks/ contingencies                          7.86
# Profit before tax                                              12.80
#
#                                                  2025-03-31 00:00:00  \
# Income
# Interest & Discount                                           159.86
# Other receipts (including non-operating income)                28.54
# Total Income                                                  188.40
# Interest paid                                                 109.37
# Operating Expenses                                             42.35
# Other Operating expenses                                        7.35
# Total operating expenses                                       49.70
# Operating Profit before provisions & taxes                     29.33
# Provision against risks/ contingencies                         15.79
# Profit before tax                                              13.54
#
#                                                  2026-03-31 00:00:00  % change
# Income
# Interest & Discount                                           193.78     21.22
# Other receipts (including non-operating income)                20.78    -27.19
# Total Income                                                  214.56     13.89
# Interest paid                                                 144.26     31.90
# Operating Expenses                                             39.44     -6.87
# Other Operating expenses                                        4.91    -33.20
# Total operating expenses                                       44.35    -10.76
# Operating Profit before provisions & taxes                     25.95    -11.52
# Provision against risks/ contingencies                          7.53    -52.31
# Profit before tax                                              18.42     36.04

# %%
# @title
# plottng YoY change in P&L Items

fig=plt.figure(figsize=(20,10))

c = ['red', 'blue', 'magenta', 'orange', 'brown', 'green', 'cyan']
bars = plt.bar(df7.index[np.abs(df7['% change']!=0)], df7['% change'][np.abs(df7['% change']!=0)], color = c)

# Add value labels
plt.bar_label(bars, fmt='%.1f%%', padding=5, fontsize=13)

plt.xticks(rotation = 90, fontsize = 20)
plt.axhline(-15, linestyle = 'dashed')
plt.axhline(15, linestyle = 'dashed')
plt.title(f'Movement of P&L Items as on {df7.columns[-2].date()}', fontsize = 20)
plt.xlabel('P&L item', fontsize = 20)
plt.ylabel('% change over prev year', fontsize = 20)

plt.show()

# %%
# @title
# Creating P&L variables for analysis

df7.drop(['% change'], axis =1, inplace = True)
sales= df7.loc['Total Income']

PBT= sales - df7.loc['Interest paid']- df7.loc['Total operating expenses']- df7.loc['Provision against risks/ contingencies']

total_assets = df2.loc['Cash + Balance with CBSL ']+\
df2.loc['Balances with other Banks']+\
df2.loc['Balances with other Banks as FDR']+\
df2.loc['Securities bought under repo']+\
df2.loc['Investments (Amortised cost)']+df2.loc['Loans & Advances (Amortised cost)']+\
df2.loc['Interest Receivable']+\
df2.loc['Bills Purchased & Discounted']+\
df2.loc['Fixed Assets']+ df2.loc['Investment in properties'] + df2.loc['Other Assets']


capital= df2.loc['Paid up share capital']+ df2.loc['Reserve Fund']


# Calculating average total asset as sum of opening and closing total asset

avg_total_assets={}
for i in range(1,len(df2.columns)):
    avg_total_assets[df2.columns[i]]=round((total_assets[i-1]+total_assets[i])/2,2)


avg_total_assets=list(avg_total_assets.values())
avg_total_assets.insert(0,0)


avg_total_capital={}
for j in range(1,len(df2.columns)):
    avg_total_capital[df2.columns[j]]=round((capital[j-1]+capital[j])/2,2)


avg_total_capital=list(avg_total_capital.values())
avg_total_capital.insert(0,0)

# Calculating the Ratios as sum of opening and closing total asset

PBT_to_Sales = PBT/sales

sales_to_avg_total_asset= sales/avg_total_assets

avg_assets_to_capital={}
for i in range(1,len(avg_total_assets)):
    avg_assets_to_capital[df2.columns[i]]= avg_total_assets[i]/avg_total_capital[i]

avg_assets_to_capital=list(avg_assets_to_capital.values())
avg_assets_to_capital.insert(0,0)

# %%
# @title
data=np.array([sales,PBT,avg_total_assets,avg_total_capital])
A=pd.DataFrame(data, columns=col_ind, index=['Sales','PBT','Avg_Tot_Assets','Avg_Tot_Capital'])

# %%
# @title
A
# Out:
#                  2013-03-31  2014-03-31  2015-03-31  2016-03-31  2017-03-31  \
# Sales                 60.54       76.30       91.59      101.39      116.13
# PBT                    4.52        4.67        5.67        5.94        7.85
# Avg_Tot_Assets         0.00      818.28      921.44      998.78     1118.30
# Avg_Tot_Capital        0.00      105.09      109.50      113.83      118.02
#
#                  2018-03-31  2019-03-31  2020-03-31  2021-03-31  2022-03-31  \
# Sales                120.38      128.20      139.20      145.03      162.16
# PBT                    7.20        9.96       10.25       12.03       14.34
# Avg_Tot_Assets      1248.34     1420.89     1551.11     1641.52     1833.07
# Avg_Tot_Capital      123.28      130.43      140.60      153.52      191.83
#
#                  2023-03-31  2024-03-31  2025-03-31  2026-03-31
# Sales                171.38      171.91      188.40      214.56
# PBT                   12.42       12.80       13.54       18.42
# Avg_Tot_Assets      2099.69     2312.26     2467.94     2716.08
# Avg_Tot_Capital      231.70      243.38      266.79      287.18

# %%
# @title
ratio_data=np.array([PBT_to_Sales,sales_to_avg_total_asset,avg_assets_to_capital])

# %%
# @title
B=pd.DataFrame(ratio_data, columns=col_ind, index=['PBT/Income','Tot Income/Avg Assets','Avg Assets/Capital'])

# %%
# @title
C=B.iloc[:,1:len(B.columns)]

# %%
# @title
C
# Out:
#                        2014-03-31  2015-03-31  2016-03-31  2017-03-31  \
# PBT/Income               0.061206    0.061906    0.058586    0.067597
# Tot Income/Avg Assets    0.093244    0.099399    0.101514    0.103845
# Avg Assets/Capital       7.786469    8.414977    8.774313    9.475513
#
#                        2018-03-31  2019-03-31  2020-03-31  2021-03-31  \
# PBT/Income               0.059811    0.077691    0.073635    0.082948
# Tot Income/Avg Assets    0.096432    0.090225    0.089742    0.088351
# Avg Assets/Capital      10.126055   10.893889   11.032077   10.692548
#
#                        2022-03-31  2023-03-31  2024-03-31  2025-03-31  \
# PBT/Income               0.088431    0.072471    0.074458    0.071868
# Tot Income/Avg Assets    0.088464    0.081622    0.074347    0.076339
# Avg Assets/Capital       9.555700    9.062106    9.500616    9.250497
#
#                        2026-03-31
# PBT/Income               0.085850
# Tot Income/Avg Assets    0.078996
# Avg Assets/Capital       9.457762

# %% [markdown]
# ### 2.1 Return on Capital Employed (ROCE) Analysis

# %%
# @title
fig=plt.figure(figsize=(16,4))
fig.suptitle('Trend in ROCE Components', fontsize=15)

plt.subplot(1,3,1)
plt.plot(C.columns,C.iloc[0])
plt.title('Trend in Profit Margin (PBT/Tot Income)')
plt.xticks(rotation=45)

plt.subplot(1,3,2)
plt.plot(C.columns,C.iloc[1], color = 'brown')
plt.title('Trend in Tot Income/Avg Asset')
plt.xticks(rotation=45)

plt.subplot(1,3,3)
plt.plot(C.columns,C.iloc[2], color = 'green')
plt.title('Trend in Avg Asset/Capital')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### 2.2 Components of Profit Margin (PBT/Tot Income)

# %% [markdown]
# We further break PBT into sub-components to analyze the trend of the period:
#
#
#
# $$ \frac {PBT} {Tot Income} = \frac {Interest\ Income} {Tot Income} \ + \  \frac {Other\ Receipts} {Tot Income}  \ - \  \frac {Interest Paid} {Tot Income} - \  \frac {Operating \ Expense} {Tot Income} - \  \frac {Other\ Operating\ Expense} {Tot Income} - \  \frac {Provision} {Tot Income} $$

# %%
# @title
df7
# Out:
#                                                  2013-03-31 00:00:00  \
# Income
# Interest & Discount                                            54.23
# Other receipts (including non-operating income)                 6.31
# Total Income                                                   60.54
# Interest paid                                                  31.58
# Operating Expenses                                             14.58
# Other Operating expenses                                        2.42
# Total operating expenses                                       17.00
# Operating Profit before provisions & taxes                     11.96
# Provision against risks/ contingencies                          7.44
# Profit before tax                                               4.52
#
#                                                  2014-03-31 00:00:00  \
# Income
# Interest & Discount                                            67.48
# Other receipts (including non-operating income)                 8.82
# Total Income                                                   76.30
# Interest paid                                                  45.40
# Operating Expenses                                             15.81
# Other Operating expenses                                        2.53
# Total operating expenses                                       18.34
# Operating Profit before provisions & taxes                     12.56
# Provision against risks/ contingencies                          7.89
# Profit before tax                                               4.67
#
#                                                  2015-03-31 00:00:00  \
# Income
# Interest & Discount                                            77.76
# Other receipts (including non-operating income)                13.83
# Total Income                                                   91.59
# Interest paid                                                  54.19
# Operating Expenses                                             18.71
# Other Operating expenses                                        2.69
# Total operating expenses                                       21.40
# Operating Profit before provisions & taxes                     16.00
# Provision against risks/ contingencies                         10.33
# Profit before tax                                               5.67
#
#                                                  2016-03-31 00:00:00  \
# Income
# Interest & Discount                                            88.37
# Other receipts (including non-operating income)                13.02
# Total Income                                                  101.39
# Interest paid                                                  62.62
# Operating Expenses                                             21.19
# Other Operating expenses                                        2.79
# Total operating expenses                                       23.98
# Operating Profit before provisions & taxes                     14.79
# Provision against risks/ contingencies                          8.85
# Profit before tax                                               5.94
#
#                                                  2017-03-31 00:00:00  \
# Income
# Interest & Discount                                           100.76
# Other receipts (including non-operating income)                15.37
# Total Income                                                  116.13
# Interest paid                                                  71.07
# Operating Expenses                                             22.33
# Other Operating expenses                                        3.38
# Total operating expenses                                       25.71
# Operating Profit before provisions & taxes                     19.35
# Provision against risks/ contingencies                         11.50
# Profit before tax                                               7.85
#
#                                                  2018-03-31 00:00:00  \
# Income
# Interest & Discount                                           108.14
# Other receipts (including non-operating income)                12.24
# Total Income                                                  120.38
# Interest paid                                                  76.32
# Operating Expenses                                             23.52
# Other Operating expenses                                        5.02
# Total operating expenses                                       28.54
# Operating Profit before provisions & taxes                     15.52
# Provision against risks/ contingencies                          8.32
# Profit before tax                                               7.20
#
#                                                  2019-03-31 00:00:00  \
# Income
# Interest & Discount                                           115.65
# Other receipts (including non-operating income)                12.55
# Total Income                                                  128.20
# Interest paid                                                  82.74
# Operating Expenses                                             24.08
# Other Operating expenses                                        5.64
# Total operating expenses                                       29.72
# Operating Profit before provisions & taxes                     15.74
# Provision against risks/ contingencies                          5.78
# Profit before tax                                               9.96
#
#                                                  2020-03-31 00:00:00  \
# Income
# Interest & Discount                                           120.20
# Other receipts (including non-operating income)                19.00
# Total Income                                                  139.20
# Interest paid                                                  82.44
# Operating Expenses                                             27.14
# Other Operating expenses                                        7.40
# Total operating expenses                                       34.54
# Operating Profit before provisions & taxes                     22.22
# Provision against risks/ contingencies                         11.97
# Profit before tax                                              10.25
#
#                                                  2021-03-31 00:00:00  \
# Income
# Interest & Discount                                           128.60
# Other receipts (including non-operating income)                16.43
# Total Income                                                  145.03
# Interest paid                                                  86.51
# Operating Expenses                                             28.76
# Other Operating expenses                                        5.64
# Total operating expenses                                       34.40
# Operating Profit before provisions & taxes                     24.12
# Provision against risks/ contingencies                         12.09
# Profit before tax                                              12.03
#
#                                                  2022-03-31 00:00:00  \
# Income
# Interest & Discount                                           140.03
# Other receipts (including non-operating income)                22.13
# Total Income                                                  162.16
# Interest paid                                                 101.85
# Operating Expenses                                             29.84
# Other Operating expenses                                        6.41
# Total operating expenses                                       36.25
# Operating Profit before provisions & taxes                     24.06
# Provision against risks/ contingencies                          9.72
# Profit before tax                                              14.34
#
#                                                  2023-03-31 00:00:00  \
# Income
# Interest & Discount                                           139.94
# Other receipts (including non-operating income)                31.44
# Total Income                                                  171.38
# Interest paid                                                 108.52
# Operating Expenses                                             34.53
# Other Operating expenses                                        6.65
# Total operating expenses                                       41.18
# Operating Profit before provisions & taxes                     21.68
# Provision against risks/ contingencies                          9.26
# Profit before tax                                              12.42
#
#                                                  2024-03-31 00:00:00  \
# Income
# Interest & Discount                                           144.11
# Other receipts (including non-operating income)                27.80
# Total Income                                                  171.91
# Interest paid                                                 104.68
# Operating Expenses                                             33.90
# Other Operating expenses                                       12.67
# Total operating expenses                                       46.57
# Operating Profit before provisions & taxes                     20.66
# Provision against risks/ contingencies                          7.86
# Profit before tax                                              12.80
#
#                                                  2025-03-31 00:00:00  \
# Income
# Interest & Discount                                           159.86
# Other receipts (including non-operating income)                28.54
# Total Income                                                  188.40
# Interest paid                                                 109.37
# Operating Expenses                                             42.35
# Other Operating expenses                                        7.35
# Total operating expenses                                       49.70
# Operating Profit before provisions & taxes                     29.33
# Provision against risks/ contingencies                         15.79
# Profit before tax                                              13.54
#
#                                                  2026-03-31 00:00:00
# Income
# Interest & Discount                                           193.78
# Other receipts (including non-operating income)                20.78
# Total Income                                                  214.56
# Interest paid                                                 144.26
# Operating Expenses                                             39.44
# Other Operating expenses                                        4.91
# Total operating expenses                                       44.35
# Operating Profit before provisions & taxes                     25.95
# Provision against risks/ contingencies                          7.53
# Profit before tax                                              18.42

# %%
# @title
# Plotting the normalised P&L items

Int_Income = df7.loc['Interest & Discount']
Int_Income_to_sales=Int_Income/sales
#print(Int_Income_to_sales)



Oth_receipts = df7.loc['Other receipts (including non-operating income)']
Oth_receipts_to_sales = Oth_receipts/sales
#print(Oth_receipts_to_sales)


Int_paid = df7.loc['Interest paid']
Int_paid_to_sales = Int_paid/sales
#print(Int_paid_to_sales)



Op_exp=df7.loc['Operating Expenses']
Op_exp_to_sales = Op_exp/sales
#print(Op_exp_to_sales)


Oth_op_exp=df7.loc['Other Operating expenses']
Oth_op_exp_to_sales=Oth_op_exp/sales
#print(Oth_op_exp_to_sales)


provision=df7.loc['Provision against risks/ contingencies']
provision_to_sales=provision/sales
#print(provision_to_sales)

# %%
# @title
#Plotting trends in P&L Accounts

fig=plt.figure(figsize=(16,15))
fig.suptitle('Trend in PBT Components, % of Tot Income', fontsize=20)
fig.tight_layout(h_pad=10)

plt.subplot(3,2,1)
#plt.plot(data2.columns,data2.iloc[0], color = 'brown')
plt.plot(Int_Income_to_sales, color = 'brown')
plt.title('Trend in Interest & Discount')

plt.subplot(3,2,2)
plt.plot(Oth_receipts_to_sales, color = 'green')
plt.title('Trend in Oth Receipts')

plt.subplot(3,2,3)
plt.plot(Int_paid_to_sales, color = 'magenta')
plt.title('Trend in Interest Paid')

plt.subplot(3,2,4)
plt.plot(Op_exp_to_sales)
plt.title('Trend in Op Exp')

plt.subplot(3,2,5)
plt.plot(Oth_op_exp_to_sales, color = 'purple')
plt.title('Trend in Oth Op Exp')

plt.subplot(3,2,6)
plt.plot(provision_to_sales, color = 'olive')
plt.title('Trend in Provisios/Contingencies')

plt.show()
