# %% [markdown]
# <a href="https://colab.research.google.com/github/AshutoshJaiswal11/Financial_Analysis/blob/main/Financial_Analysis_27062026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Analysis of Financial Statements: XYZ Bank<center>

# %%
# Import the necessary libraries

import os
import pandas as pd
import matplotlib.pyplot as plt
import cufflinks as cf
import numpy as np


import missingno
import datetime as dt

import warnings
warnings.filterwarnings('ignore')
import plotly.express
import time

# %%
os.getcwd()
# Out:
# '/Users/ashutoshjaiswal/Documents/Python/Models and Codes/Financial Statement and Business Model Analysis'

# %%
df1 = pd.read_excel('Financial_Template_2026_1.xlsx',index_col=0, parse_dates=True)

# %%
df1
# Out:
#                                                 2013-03-31  2014-03-31  \
# ITEMS
# Capital                                            14.5700   14.840000
# Reserve Fund                                       88.2000   92.570000
# Other Reserve                                       0.0000    0.000000
# Deposits                                          565.1500  642.560000
# Deposits- Demand                                  237.3630  218.470400
# Deposits- Term                                    327.7870  424.089600
# Borrowings                                         61.2300  119.662500
# Borrowings- Interbank                               9.7968   13.162875
# Borrowings- Repo                                   51.4332  106.499625
# Interest Payable                                    0.5900    0.720000
# Other Liabilities - Derivatives, Sub Debt etc.     11.0600   13.910000
# Profit (Loss)                                       4.5200    4.670000
# Current Tax Liabilities                             1.1300    1.167500
# Cash + Balance with CB                             36.6100   36.990000
# Balances with other Banks                          10.5000    6.020000
# Balances with other Banks as FDR                   76.2100   84.830000
# Securities bought under repo                        0.0000    0.000000
# Investments                                       279.6400  361.000000
# Investments (Amortised cost)                      212.5264  306.850000
# Investments (non-Amortised cost)                   67.1136   54.150000
# Loans & Advances (Amortised cost)                 314.7800  367.390000
# Interest Receivable                                 7.4200    9.850000
# Bills Purchased & Discounted                        1.8100    0.570000
# Fixed Assets                                        7.0800    9.460000
# Investment in properties                            0.0000    0.000000
# Other Assets                                       12.4000   13.990000
# Total Assets                                      746.4500  890.100000
#
#                                                 2015-03-31  2016-03-31  \
# ITEMS
# Capital                                           15.64000     15.8300
# Reserve Fund                                      95.94000    100.2500
# Other Reserve                                      0.00000      0.0000
# Deposits                                         746.98000    872.8800
# Deposits- Demand                                 209.15440    235.6776
# Deposits- Term                                   537.82560    637.2024
# Borrowings                                        69.51250     26.8450
# Borrowings- Interbank                             12.51225      5.9059
# Borrowings- Repo                                  57.00025     20.9391
# Interest Payable                                   0.91000      0.8900
# Other Liabilities - Derivatives, Sub Debt etc.    16.70000     20.6600
# Profit (Loss)                                      5.67000      5.9400
# Current Tax Liabilities                            1.41750      1.4850
# Cash + Balance with CB                            36.67000     42.4000
# Balances with other Banks                          9.18000      5.6800
# Balances with other Banks as FDR                 113.85000     94.1600
# Securities bought under repo                       0.00000      0.0000
# Investments                                      326.15000    343.9400
# Investments (Amortised cost)                     290.27350    216.6822
# Investments (non-Amortised cost)                  35.87650    127.2578
# Loans & Advances (Amortised cost)                424.98000    508.2300
# Interest Receivable                                9.69000      9.9000
# Bills Purchased & Discounted                       0.61000      3.1000
# Fixed Assets                                       9.03000     12.8200
# Investment in properties                           0.00000      0.0000
# Other Assets                                      22.61000     24.5500
# Total Assets                                     952.77000   1044.7800
#
#                                                  2017-03-31  2018-03-31  \
# ITEMS
# Capital                                           15.220000     15.3800
# Reserve Fund                                     104.740000    111.2200
# Other Reserve                                      0.000000      0.0000
# Deposits                                        1039.180000   1142.6100
# Deposits- Demand                                 342.929400    354.2091
# Deposits- Term                                   696.250600    788.4009
# Borrowings                                         1.947500      1.3000
# Borrowings- Interbank                              0.447925      0.1560
# Borrowings- Repo                                   1.499575      1.1440
# Interest Payable                                   0.880000      1.0900
# Other Liabilities - Derivatives, Sub Debt etc.    20.030000     24.2600
# Profit (Loss)                                      7.850000      7.2000
# Current Tax Liabilities                            1.962500      1.8000
# Cash + Balance with CB                            61.340000     57.2100
# Balances with other Banks                         10.190000      9.7100
# Balances with other Banks as FDR                 150.970000    180.5100
# Securities bought under repo                      24.960000     29.9700
# Investments                                      304.660000    293.1900
# Investments (Amortised cost)                     271.147400    216.9606
# Investments (non-Amortised cost)                  33.512600     76.2294
# Loans & Advances (Amortised cost)                589.450000    678.1600
# Interest Receivable                               13.470000     11.1800
# Bills Purchased & Discounted                       3.620000      3.0200
# Fixed Assets                                      15.110000     21.3900
# Investment in properties                           0.000000      0.0000
# Other Assets                                      18.040000     20.5200
# Total Assets                                    1191.810000   1304.8600
#
#                                                 2019-03-31  2020-03-31  \
# ITEMS
# Capital                                            16.1300    18.35000
# Reserve Fund                                      118.1300   128.60000
# Other Reserve                                       0.0000     0.00000
# Deposits                                         1355.4300  1366.59000
# Deposits- Demand                                  569.2806   464.64060
# Deposits- Term                                    786.1494   901.94940
# Borrowings                                         11.0800    12.06500
# Borrowings- Interbank                               1.8836     2.53365
# Borrowings- Repo                                    9.1964     9.53135
# Interest Payable                                    1.2100     1.19000
# Other Liabilities - Derivatives, Sub Debt etc.     22.4900    25.69000
# Profit (Loss)                                       9.9600    10.25000
# Current Tax Liabilities                             2.4900     2.56250
# Cash + Balance with CB                             60.3600    78.08000
# Balances with other Banks                          14.8400    20.73000
# Balances with other Banks as FDR                  190.0800   114.54000
# Securities bought under repo                      125.0000    12.15750
# Investments                                       351.7600   379.99000
# Investments (Amortised cost)                      253.2672   277.39270
# Investments (non-Amortised cost)                   98.4928   102.59730
# Loans & Advances (Amortised cost)                 728.4800   901.47000
# Interest Receivable                                13.6700    12.23000
# Bills Purchased & Discounted                       13.5100     2.39000
# Fixed Assets                                       19.4400    18.04000
# Investment in properties                            0.0000     0.00000
# Other Assets                                       19.7800    25.67000
# Total Assets                                     1536.9200  1565.29750
#
#                                                 2021-03-31  2022-03-31  \
# ITEMS
# Capital                                           20.15000     21.4300
# Reserve Fund                                     139.95000    202.1300
# Other Reserve                                      0.00000      0.0000
# Deposits                                        1498.51000   1663.2600
# Deposits- Demand                                 569.43380    415.8150
# Deposits- Term                                   929.07620   1247.4450
# Borrowings                                        14.26500     14.0300
# Borrowings- Interbank                              2.99565      3.2269
# Borrowings- Repo                                  11.26935     10.8031
# Interest Payable                                   0.21000      0.3000
# Other Liabilities - Derivatives, Sub Debt etc.    29.62000     29.3200
# Profit (Loss)                                     12.03000     14.3400
# Current Tax Liabilities                            3.00750      3.5850
# Cash + Balance with CB                            93.60000    176.2400
# Balances with other Banks                          9.32000     11.6800
# Balances with other Banks as FDR                  98.81000    151.4600
# Securities bought under repo                      15.92250     15.5150
# Investments                                      434.14000    429.4500
# Investments (Amortised cost)                     230.09420    283.4370
# Investments (non-Amortised cost)                 204.04580    146.0130
# Loans & Advances (Amortised cost)               1007.87000   1041.1400
# Interest Receivable                               10.21000     13.9900
# Bills Purchased & Discounted                       1.38000      2.1100
# Fixed Assets                                      20.79000     80.4300
# Investment in properties                           0.00000      0.0000
# Other Assets                                      25.70000     26.3800
# Total Assets                                    1717.74250   1948.3950
#
#                                                 2023-03-31  2024-03-31  \
# ITEMS
# Capital                                            23.3900     24.7400
# Reserve Fund                                      216.4600    222.1700
# Other Reserve                                       0.0000      0.0000
# Deposits                                         1967.7200   2071.3800
# Deposits- Demand                                  826.4424    745.6968
# Deposits- Term                                   1141.2776   1325.6832
# Borrowings                                         17.9900     15.6200
# Borrowings- Interbank                               2.8784      3.9050
# Borrowings- Repo                                   15.1116     11.7150
# Interest Payable                                    0.2400      0.2400
# Other Liabilities - Derivatives, Sub Debt etc.      9.6600     23.3900
# Profit (Loss)                                      12.4200     12.8000
# Current Tax Liabilities                             3.1050      3.2000
# Cash + Balance with CB                             92.9600    195.2700
# Balances with other Banks                          12.3200     28.5800
# Balances with other Banks as FDR                  153.1600     97.0800
# Securities bought under repo                       19.9350     17.2000
# Investments                                       727.4100    804.9000
# Investments (Amortised cost)                      494.6388    724.4100
# Investments (non-Amortised cost)                  232.7712     80.4900
# Loans & Advances (Amortised cost)                1043.9200   1128.7300
# Interest Receivable                                20.0000     17.2900
# Bills Purchased & Discounted                        1.4400      1.6500
# Fixed Assets                                       75.0500     69.4800
# Investment in properties                            0.0000      0.0000
# Other Assets                                      104.7900     13.3600
# Total Assets                                     2250.9850   2373.5400
#
#                                                 2025-03-31  2026-03-31
# ITEMS
# Capital                                            24.4100     23.9400
# Reserve Fund                                      262.2500    263.7600
# Other Reserve                                       0.0000      0.0000
# Deposits                                         2206.1300   2530.6600
# Deposits- Demand                                  661.8390   1088.1838
# Deposits- Term                                   1544.2910   1442.4762
# Borrowings                                         12.1100     11.2300
# Borrowings- Interbank                               2.7853      1.4599
# Borrowings- Repo                                    9.3247      9.7701
# Interest Payable                                    0.2500      0.1800
# Other Liabilities - Derivatives, Sub Debt etc.     40.2700     17.0300
# Profit (Loss)                                      13.5400     18.4200
# Current Tax Liabilities                             3.3850      4.6050
# Cash + Balance with CB                            157.0200    229.2800
# Balances with other Banks                          29.3800     23.7900
# Balances with other Banks as FDR                   87.7500    182.7000
# Securities bought under repo                       15.3450     13.6350
# Investments                                       786.7100    788.8700
# Investments (Amortised cost)                      629.3680    520.6542
# Investments (non-Amortised cost)                  157.3420    268.2158
# Loans & Advances (Amortised cost)                1327.5900   1513.3600
# Interest Receivable                                16.0600     20.6500
# Bills Purchased & Discounted                        0.3000      2.5500
# Fixed Assets                                       95.9400     89.8100
# Investment in properties                            0.0000      0.0000
# Other Assets                                       46.2500      5.1800
# Total Assets                                     2562.3450   2869.8250

# %%
# @title
df2=pd.DataFrame(df1)
print(f'Latest available Financial Year data: {str(df2.columns[-1].date())}')

# Extracting FY as column names

df2.columns = [df2.columns[i].date() for i in range(len(df2.columns))]
# Out:
# Latest available Financial Year data: 2026-03-31

# %%
df2
# Out:
#                                                 2013-03-31  2014-03-31  \
# ITEMS
# Capital                                            14.5700   14.840000
# Reserve Fund                                       88.2000   92.570000
# Other Reserve                                       0.0000    0.000000
# Deposits                                          565.1500  642.560000
# Deposits- Demand                                  237.3630  218.470400
# Deposits- Term                                    327.7870  424.089600
# Borrowings                                         61.2300  119.662500
# Borrowings- Interbank                               9.7968   13.162875
# Borrowings- Repo                                   51.4332  106.499625
# Interest Payable                                    0.5900    0.720000
# Other Liabilities - Derivatives, Sub Debt etc.     11.0600   13.910000
# Profit (Loss)                                       4.5200    4.670000
# Current Tax Liabilities                             1.1300    1.167500
# Cash + Balance with CB                             36.6100   36.990000
# Balances with other Banks                          10.5000    6.020000
# Balances with other Banks as FDR                   76.2100   84.830000
# Securities bought under repo                        0.0000    0.000000
# Investments                                       279.6400  361.000000
# Investments (Amortised cost)                      212.5264  306.850000
# Investments (non-Amortised cost)                   67.1136   54.150000
# Loans & Advances (Amortised cost)                 314.7800  367.390000
# Interest Receivable                                 7.4200    9.850000
# Bills Purchased & Discounted                        1.8100    0.570000
# Fixed Assets                                        7.0800    9.460000
# Investment in properties                            0.0000    0.000000
# Other Assets                                       12.4000   13.990000
# Total Assets                                      746.4500  890.100000
#
#                                                 2015-03-31  2016-03-31  \
# ITEMS
# Capital                                           15.64000     15.8300
# Reserve Fund                                      95.94000    100.2500
# Other Reserve                                      0.00000      0.0000
# Deposits                                         746.98000    872.8800
# Deposits- Demand                                 209.15440    235.6776
# Deposits- Term                                   537.82560    637.2024
# Borrowings                                        69.51250     26.8450
# Borrowings- Interbank                             12.51225      5.9059
# Borrowings- Repo                                  57.00025     20.9391
# Interest Payable                                   0.91000      0.8900
# Other Liabilities - Derivatives, Sub Debt etc.    16.70000     20.6600
# Profit (Loss)                                      5.67000      5.9400
# Current Tax Liabilities                            1.41750      1.4850
# Cash + Balance with CB                            36.67000     42.4000
# Balances with other Banks                          9.18000      5.6800
# Balances with other Banks as FDR                 113.85000     94.1600
# Securities bought under repo                       0.00000      0.0000
# Investments                                      326.15000    343.9400
# Investments (Amortised cost)                     290.27350    216.6822
# Investments (non-Amortised cost)                  35.87650    127.2578
# Loans & Advances (Amortised cost)                424.98000    508.2300
# Interest Receivable                                9.69000      9.9000
# Bills Purchased & Discounted                       0.61000      3.1000
# Fixed Assets                                       9.03000     12.8200
# Investment in properties                           0.00000      0.0000
# Other Assets                                      22.61000     24.5500
# Total Assets                                     952.77000   1044.7800
#
#                                                  2017-03-31  2018-03-31  \
# ITEMS
# Capital                                           15.220000     15.3800
# Reserve Fund                                     104.740000    111.2200
# Other Reserve                                      0.000000      0.0000
# Deposits                                        1039.180000   1142.6100
# Deposits- Demand                                 342.929400    354.2091
# Deposits- Term                                   696.250600    788.4009
# Borrowings                                         1.947500      1.3000
# Borrowings- Interbank                              0.447925      0.1560
# Borrowings- Repo                                   1.499575      1.1440
# Interest Payable                                   0.880000      1.0900
# Other Liabilities - Derivatives, Sub Debt etc.    20.030000     24.2600
# Profit (Loss)                                      7.850000      7.2000
# Current Tax Liabilities                            1.962500      1.8000
# Cash + Balance with CB                            61.340000     57.2100
# Balances with other Banks                         10.190000      9.7100
# Balances with other Banks as FDR                 150.970000    180.5100
# Securities bought under repo                      24.960000     29.9700
# Investments                                      304.660000    293.1900
# Investments (Amortised cost)                     271.147400    216.9606
# Investments (non-Amortised cost)                  33.512600     76.2294
# Loans & Advances (Amortised cost)                589.450000    678.1600
# Interest Receivable                               13.470000     11.1800
# Bills Purchased & Discounted                       3.620000      3.0200
# Fixed Assets                                      15.110000     21.3900
# Investment in properties                           0.000000      0.0000
# Other Assets                                      18.040000     20.5200
# Total Assets                                    1191.810000   1304.8600
#
#                                                 2019-03-31  2020-03-31  \
# ITEMS
# Capital                                            16.1300    18.35000
# Reserve Fund                                      118.1300   128.60000
# Other Reserve                                       0.0000     0.00000
# Deposits                                         1355.4300  1366.59000
# Deposits- Demand                                  569.2806   464.64060
# Deposits- Term                                    786.1494   901.94940
# Borrowings                                         11.0800    12.06500
# Borrowings- Interbank                               1.8836     2.53365
# Borrowings- Repo                                    9.1964     9.53135
# Interest Payable                                    1.2100     1.19000
# Other Liabilities - Derivatives, Sub Debt etc.     22.4900    25.69000
# Profit (Loss)                                       9.9600    10.25000
# Current Tax Liabilities                             2.4900     2.56250
# Cash + Balance with CB                             60.3600    78.08000
# Balances with other Banks                          14.8400    20.73000
# Balances with other Banks as FDR                  190.0800   114.54000
# Securities bought under repo                      125.0000    12.15750
# Investments                                       351.7600   379.99000
# Investments (Amortised cost)                      253.2672   277.39270
# Investments (non-Amortised cost)                   98.4928   102.59730
# Loans & Advances (Amortised cost)                 728.4800   901.47000
# Interest Receivable                                13.6700    12.23000
# Bills Purchased & Discounted                       13.5100     2.39000
# Fixed Assets                                       19.4400    18.04000
# Investment in properties                            0.0000     0.00000
# Other Assets                                       19.7800    25.67000
# Total Assets                                     1536.9200  1565.29750
#
#                                                 2021-03-31  2022-03-31  \
# ITEMS
# Capital                                           20.15000     21.4300
# Reserve Fund                                     139.95000    202.1300
# Other Reserve                                      0.00000      0.0000
# Deposits                                        1498.51000   1663.2600
# Deposits- Demand                                 569.43380    415.8150
# Deposits- Term                                   929.07620   1247.4450
# Borrowings                                        14.26500     14.0300
# Borrowings- Interbank                              2.99565      3.2269
# Borrowings- Repo                                  11.26935     10.8031
# Interest Payable                                   0.21000      0.3000
# Other Liabilities - Derivatives, Sub Debt etc.    29.62000     29.3200
# Profit (Loss)                                     12.03000     14.3400
# Current Tax Liabilities                            3.00750      3.5850
# Cash + Balance with CB                            93.60000    176.2400
# Balances with other Banks                          9.32000     11.6800
# Balances with other Banks as FDR                  98.81000    151.4600
# Securities bought under repo                      15.92250     15.5150
# Investments                                      434.14000    429.4500
# Investments (Amortised cost)                     230.09420    283.4370
# Investments (non-Amortised cost)                 204.04580    146.0130
# Loans & Advances (Amortised cost)               1007.87000   1041.1400
# Interest Receivable                               10.21000     13.9900
# Bills Purchased & Discounted                       1.38000      2.1100
# Fixed Assets                                      20.79000     80.4300
# Investment in properties                           0.00000      0.0000
# Other Assets                                      25.70000     26.3800
# Total Assets                                    1717.74250   1948.3950
#
#                                                 2023-03-31  2024-03-31  \
# ITEMS
# Capital                                            23.3900     24.7400
# Reserve Fund                                      216.4600    222.1700
# Other Reserve                                       0.0000      0.0000
# Deposits                                         1967.7200   2071.3800
# Deposits- Demand                                  826.4424    745.6968
# Deposits- Term                                   1141.2776   1325.6832
# Borrowings                                         17.9900     15.6200
# Borrowings- Interbank                               2.8784      3.9050
# Borrowings- Repo                                   15.1116     11.7150
# Interest Payable                                    0.2400      0.2400
# Other Liabilities - Derivatives, Sub Debt etc.      9.6600     23.3900
# Profit (Loss)                                      12.4200     12.8000
# Current Tax Liabilities                             3.1050      3.2000
# Cash + Balance with CB                             92.9600    195.2700
# Balances with other Banks                          12.3200     28.5800
# Balances with other Banks as FDR                  153.1600     97.0800
# Securities bought under repo                       19.9350     17.2000
# Investments                                       727.4100    804.9000
# Investments (Amortised cost)                      494.6388    724.4100
# Investments (non-Amortised cost)                  232.7712     80.4900
# Loans & Advances (Amortised cost)                1043.9200   1128.7300
# Interest Receivable                                20.0000     17.2900
# Bills Purchased & Discounted                        1.4400      1.6500
# Fixed Assets                                       75.0500     69.4800
# Investment in properties                            0.0000      0.0000
# Other Assets                                      104.7900     13.3600
# Total Assets                                     2250.9850   2373.5400
#
#                                                 2025-03-31  2026-03-31
# ITEMS
# Capital                                            24.4100     23.9400
# Reserve Fund                                      262.2500    263.7600
# Other Reserve                                       0.0000      0.0000
# Deposits                                         2206.1300   2530.6600
# Deposits- Demand                                  661.8390   1088.1838
# Deposits- Term                                   1544.2910   1442.4762
# Borrowings                                         12.1100     11.2300
# Borrowings- Interbank                               2.7853      1.4599
# Borrowings- Repo                                    9.3247      9.7701
# Interest Payable                                    0.2500      0.1800
# Other Liabilities - Derivatives, Sub Debt etc.     40.2700     17.0300
# Profit (Loss)                                      13.5400     18.4200
# Current Tax Liabilities                             3.3850      4.6050
# Cash + Balance with CB                            157.0200    229.2800
# Balances with other Banks                          29.3800     23.7900
# Balances with other Banks as FDR                   87.7500    182.7000
# Securities bought under repo                       15.3450     13.6350
# Investments                                       786.7100    788.8700
# Investments (Amortised cost)                      629.3680    520.6542
# Investments (non-Amortised cost)                  157.3420    268.2158
# Loans & Advances (Amortised cost)                1327.5900   1513.3600
# Interest Receivable                                16.0600     20.6500
# Bills Purchased & Discounted                        0.3000      2.5500
# Fixed Assets                                       95.9400     89.8100
# Investment in properties                            0.0000      0.0000
# Other Assets                                       46.2500      5.1800
# Total Assets                                     2562.3450   2869.8250

# %% [markdown]
# # 1. Financial Perfromance Analysis
#
# We are looking at time series data and examining YoY change for lastest FY data

# %%
# Computing % change in last FY BS items over previous year

df2.fillna(0)
df2['% change'] = np.round((np.divide(np.array(df2.iloc[:,-1:]), np.array(df2.iloc[:,-2:-1]))-1)*100,2)
df2.fillna(0, inplace = True)

# %%
# @title

# Plotting change in all BS items

fig = plt.figure(figsize=(20, 10))

c = ['red', 'blue', 'magenta', 'orange', 'brown', 'green', 'cyan']

bars = plt.bar(df2.index[np.abs(df2['% change']!=0)], df2['% change'][np.abs(df2['% change']!=0)], color=c)

# Add value labels
plt.bar_label(bars, fmt='%.1f%%', padding=5, fontsize=13)

plt.xticks(rotation=90, fontsize=15)
plt.axhline(-20, linestyle='dashed')
plt.axhline(20, linestyle='dashed')

plt.xlabel('Balance Sheet Item', fontsize=20)
plt.ylabel('% change over prev year', fontsize=20)
plt.title(f'Movement of Balance Sheet Items as on {df2.columns[-2]}', fontsize=20)
plt.show()

# %%
# @title
# re-frame the data file for further processing

df2.drop(['% change'], axis = 1, inplace= True)
col_ind = [df2.columns[i] for i in range(len(df2.columns))]
df2
# Out:
#                                                 2013-03-31  2014-03-31  \
# ITEMS
# Capital                                            14.5700   14.840000
# Reserve Fund                                       88.2000   92.570000
# Other Reserve                                       0.0000    0.000000
# Deposits                                          565.1500  642.560000
# Deposits- Demand                                  237.3630  218.470400
# Deposits- Term                                    327.7870  424.089600
# Borrowings                                         61.2300  119.662500
# Borrowings- Interbank                               9.7968   13.162875
# Borrowings- Repo                                   51.4332  106.499625
# Interest Payable                                    0.5900    0.720000
# Other Liabilities - Derivatives, Sub Debt etc.     11.0600   13.910000
# Profit (Loss)                                       4.5200    4.670000
# Current Tax Liabilities                             1.1300    1.167500
# Cash + Balance with CB                             36.6100   36.990000
# Balances with other Banks                          10.5000    6.020000
# Balances with other Banks as FDR                   76.2100   84.830000
# Securities bought under repo                        0.0000    0.000000
# Investments                                       279.6400  361.000000
# Investments (Amortised cost)                      212.5264  306.850000
# Investments (non-Amortised cost)                   67.1136   54.150000
# Loans & Advances (Amortised cost)                 314.7800  367.390000
# Interest Receivable                                 7.4200    9.850000
# Bills Purchased & Discounted                        1.8100    0.570000
# Fixed Assets                                        7.0800    9.460000
# Investment in properties                            0.0000    0.000000
# Other Assets                                       12.4000   13.990000
# Total Assets                                      746.4500  890.100000
#
#                                                 2015-03-31  2016-03-31  \
# ITEMS
# Capital                                           15.64000     15.8300
# Reserve Fund                                      95.94000    100.2500
# Other Reserve                                      0.00000      0.0000
# Deposits                                         746.98000    872.8800
# Deposits- Demand                                 209.15440    235.6776
# Deposits- Term                                   537.82560    637.2024
# Borrowings                                        69.51250     26.8450
# Borrowings- Interbank                             12.51225      5.9059
# Borrowings- Repo                                  57.00025     20.9391
# Interest Payable                                   0.91000      0.8900
# Other Liabilities - Derivatives, Sub Debt etc.    16.70000     20.6600
# Profit (Loss)                                      5.67000      5.9400
# Current Tax Liabilities                            1.41750      1.4850
# Cash + Balance with CB                            36.67000     42.4000
# Balances with other Banks                          9.18000      5.6800
# Balances with other Banks as FDR                 113.85000     94.1600
# Securities bought under repo                       0.00000      0.0000
# Investments                                      326.15000    343.9400
# Investments (Amortised cost)                     290.27350    216.6822
# Investments (non-Amortised cost)                  35.87650    127.2578
# Loans & Advances (Amortised cost)                424.98000    508.2300
# Interest Receivable                                9.69000      9.9000
# Bills Purchased & Discounted                       0.61000      3.1000
# Fixed Assets                                       9.03000     12.8200
# Investment in properties                           0.00000      0.0000
# Other Assets                                      22.61000     24.5500
# Total Assets                                     952.77000   1044.7800
#
#                                                  2017-03-31  2018-03-31  \
# ITEMS
# Capital                                           15.220000     15.3800
# Reserve Fund                                     104.740000    111.2200
# Other Reserve                                      0.000000      0.0000
# Deposits                                        1039.180000   1142.6100
# Deposits- Demand                                 342.929400    354.2091
# Deposits- Term                                   696.250600    788.4009
# Borrowings                                         1.947500      1.3000
# Borrowings- Interbank                              0.447925      0.1560
# Borrowings- Repo                                   1.499575      1.1440
# Interest Payable                                   0.880000      1.0900
# Other Liabilities - Derivatives, Sub Debt etc.    20.030000     24.2600
# Profit (Loss)                                      7.850000      7.2000
# Current Tax Liabilities                            1.962500      1.8000
# Cash + Balance with CB                            61.340000     57.2100
# Balances with other Banks                         10.190000      9.7100
# Balances with other Banks as FDR                 150.970000    180.5100
# Securities bought under repo                      24.960000     29.9700
# Investments                                      304.660000    293.1900
# Investments (Amortised cost)                     271.147400    216.9606
# Investments (non-Amortised cost)                  33.512600     76.2294
# Loans & Advances (Amortised cost)                589.450000    678.1600
# Interest Receivable                               13.470000     11.1800
# Bills Purchased & Discounted                       3.620000      3.0200
# Fixed Assets                                      15.110000     21.3900
# Investment in properties                           0.000000      0.0000
# Other Assets                                      18.040000     20.5200
# Total Assets                                    1191.810000   1304.8600
#
#                                                 2019-03-31  2020-03-31  \
# ITEMS
# Capital                                            16.1300    18.35000
# Reserve Fund                                      118.1300   128.60000
# Other Reserve                                       0.0000     0.00000
# Deposits                                         1355.4300  1366.59000
# Deposits- Demand                                  569.2806   464.64060
# Deposits- Term                                    786.1494   901.94940
# Borrowings                                         11.0800    12.06500
# Borrowings- Interbank                               1.8836     2.53365
# Borrowings- Repo                                    9.1964     9.53135
# Interest Payable                                    1.2100     1.19000
# Other Liabilities - Derivatives, Sub Debt etc.     22.4900    25.69000
# Profit (Loss)                                       9.9600    10.25000
# Current Tax Liabilities                             2.4900     2.56250
# Cash + Balance with CB                             60.3600    78.08000
# Balances with other Banks                          14.8400    20.73000
# Balances with other Banks as FDR                  190.0800   114.54000
# Securities bought under repo                      125.0000    12.15750
# Investments                                       351.7600   379.99000
# Investments (Amortised cost)                      253.2672   277.39270
# Investments (non-Amortised cost)                   98.4928   102.59730
# Loans & Advances (Amortised cost)                 728.4800   901.47000
# Interest Receivable                                13.6700    12.23000
# Bills Purchased & Discounted                       13.5100     2.39000
# Fixed Assets                                       19.4400    18.04000
# Investment in properties                            0.0000     0.00000
# Other Assets                                       19.7800    25.67000
# Total Assets                                     1536.9200  1565.29750
#
#                                                 2021-03-31  2022-03-31  \
# ITEMS
# Capital                                           20.15000     21.4300
# Reserve Fund                                     139.95000    202.1300
# Other Reserve                                      0.00000      0.0000
# Deposits                                        1498.51000   1663.2600
# Deposits- Demand                                 569.43380    415.8150
# Deposits- Term                                   929.07620   1247.4450
# Borrowings                                        14.26500     14.0300
# Borrowings- Interbank                              2.99565      3.2269
# Borrowings- Repo                                  11.26935     10.8031
# Interest Payable                                   0.21000      0.3000
# Other Liabilities - Derivatives, Sub Debt etc.    29.62000     29.3200
# Profit (Loss)                                     12.03000     14.3400
# Current Tax Liabilities                            3.00750      3.5850
# Cash + Balance with CB                            93.60000    176.2400
# Balances with other Banks                          9.32000     11.6800
# Balances with other Banks as FDR                  98.81000    151.4600
# Securities bought under repo                      15.92250     15.5150
# Investments                                      434.14000    429.4500
# Investments (Amortised cost)                     230.09420    283.4370
# Investments (non-Amortised cost)                 204.04580    146.0130
# Loans & Advances (Amortised cost)               1007.87000   1041.1400
# Interest Receivable                               10.21000     13.9900
# Bills Purchased & Discounted                       1.38000      2.1100
# Fixed Assets                                      20.79000     80.4300
# Investment in properties                           0.00000      0.0000
# Other Assets                                      25.70000     26.3800
# Total Assets                                    1717.74250   1948.3950
#
#                                                 2023-03-31  2024-03-31  \
# ITEMS
# Capital                                            23.3900     24.7400
# Reserve Fund                                      216.4600    222.1700
# Other Reserve                                       0.0000      0.0000
# Deposits                                         1967.7200   2071.3800
# Deposits- Demand                                  826.4424    745.6968
# Deposits- Term                                   1141.2776   1325.6832
# Borrowings                                         17.9900     15.6200
# Borrowings- Interbank                               2.8784      3.9050
# Borrowings- Repo                                   15.1116     11.7150
# Interest Payable                                    0.2400      0.2400
# Other Liabilities - Derivatives, Sub Debt etc.      9.6600     23.3900
# Profit (Loss)                                      12.4200     12.8000
# Current Tax Liabilities                             3.1050      3.2000
# Cash + Balance with CB                             92.9600    195.2700
# Balances with other Banks                          12.3200     28.5800
# Balances with other Banks as FDR                  153.1600     97.0800
# Securities bought under repo                       19.9350     17.2000
# Investments                                       727.4100    804.9000
# Investments (Amortised cost)                      494.6388    724.4100
# Investments (non-Amortised cost)                  232.7712     80.4900
# Loans & Advances (Amortised cost)                1043.9200   1128.7300
# Interest Receivable                                20.0000     17.2900
# Bills Purchased & Discounted                        1.4400      1.6500
# Fixed Assets                                       75.0500     69.4800
# Investment in properties                            0.0000      0.0000
# Other Assets                                      104.7900     13.3600
# Total Assets                                     2250.9850   2373.5400
#
#                                                 2025-03-31  2026-03-31
# ITEMS
# Capital                                            24.4100     23.9400
# Reserve Fund                                      262.2500    263.7600
# Other Reserve                                       0.0000      0.0000
# Deposits                                         2206.1300   2530.6600
# Deposits- Demand                                  661.8390   1088.1838
# Deposits- Term                                   1544.2910   1442.4762
# Borrowings                                         12.1100     11.2300
# Borrowings- Interbank                               2.7853      1.4599
# Borrowings- Repo                                    9.3247      9.7701
# Interest Payable                                    0.2500      0.1800
# Other Liabilities - Derivatives, Sub Debt etc.     40.2700     17.0300
# Profit (Loss)                                      13.5400     18.4200
# Current Tax Liabilities                             3.3850      4.6050
# Cash + Balance with CB                            157.0200    229.2800
# Balances with other Banks                          29.3800     23.7900
# Balances with other Banks as FDR                   87.7500    182.7000
# Securities bought under repo                       15.3450     13.6350
# Investments                                       786.7100    788.8700
# Investments (Amortised cost)                      629.3680    520.6542
# Investments (non-Amortised cost)                  157.3420    268.2158
# Loans & Advances (Amortised cost)                1327.5900   1513.3600
# Interest Receivable                                16.0600     20.6500
# Bills Purchased & Discounted                        0.3000      2.5500
# Fixed Assets                                       95.9400     89.8100
# Investment in properties                            0.0000      0.0000
# Other Assets                                       46.2500      5.1800
# Total Assets                                     2562.3450   2869.8250

# %% [markdown]
# ### 1.1 Visualizing Financial Parameters of Interest

# %%
# plotting the timeseries plot of balance sheet items over the years

fig=plt.figure(figsize=(30,35))
#fig.tight_layout(h_pad= 0.5, w_pad= .5)

items = round(len(df2.index)/4)

for i in range(1,len(df2.index)):
    plt.subplot(items, 4, i)
    plt.plot(df2.columns,df2.iloc[i-1])
    plt.xticks(fontsize=15)
    plt.title(f'{df2.index[i-1]}', fontsize=20)

plt.suptitle('Trend in Key Financials',fontsize = 30, y = 1.01)
plt.tight_layout(h_pad=0.5, w_pad=0.5, rect=[0, 0, 1, 1])
plt.show()

# %% [markdown]
# # 2. Earnings Analysis
#
# Here we disect the components of Return on Capital Employed (ROCE) into various sub-components to gain insight into sources and quality of earnings. A typical company's P&L can be viewed as consisting of following items:
#
# Sales
#
# -COGS
# ________________
# **Gross Profit**
#
# -SG&A
# ___________________
# **Operating Profit**
#
# -Depreciation & Provisions
#
# __________________________
# **EBIT**
#
# -Interest paid
# ____________________________
# **EBT**
#
# -Taxes
# _________________________
# **Net Income**
#
#
#
#
# However, in case of banks, Interest paid is treated as COGS since that is the cost paid by banks to generate sales i.e., earn income on its assets.
#
# and ROCE may be expressed as:

# %% [markdown]
# $$ROCE=\frac{PBT} {Average\ Capital}$$

# %% [markdown]
# For a bank, we make the following adjustments:
#
# **Total Income** = Interest Income + Other Income
#
# **PBT** = Interest Income + Other Income - Interest Expense - Total Operating Exp - Provisions
#
# **Average Capital** = (Opening Capital + Closing Capital)/2
#
# **Average Total Assets** = (Opening Total Assets + Closing Total Assets)/2
#
# And, we break the ROCE in sub-components to analyze the bank's income drivers:

# %% [markdown]
# $$ROCE= \frac {PBT} {Tot Income} \ X \  \frac {Tot Income} {Average\ Total\ Assets}  \ X \  \frac {Average\ Total\ Assets} {Average \ Capital}$$

# %%
# @title
# Reading the p&L data

df7=pd.read_excel('Financial_Template_2026_1.xlsx',sheet_name='P&L',index_col=0, parse_dates=True)
df7.fillna(0)
df7['% change'] = np.round((np.divide(np.array(df7.iloc[:,-1:]), np.array(df7.iloc[:,-2:-1]))-1)*100,2)

# %%
df7
# Out:
#                                    2013-03-31 00:00:00  2014-03-31 00:00:00  \
# Income
# Interest Income                                  54.23                67.48
# Other Income                                      6.31                 8.82
# Total Income                                     60.54                76.30
# Interest Exp                                     31.58                45.40
# Operating Exp                                    14.58                15.81
# Other Operating Exp                               2.42                 2.53
# Total operating Exp                              17.00                18.34
# Profit before provisions & tax                   11.96                12.56
# Provision (Loans & contingencies)                 7.44                 7.89
# Profit before tax                                 4.52                 4.67
#
#                                    2015-03-31 00:00:00  2016-03-31 00:00:00  \
# Income
# Interest Income                                  77.76                88.37
# Other Income                                     13.83                13.02
# Total Income                                     91.59               101.39
# Interest Exp                                     54.19                62.62
# Operating Exp                                    18.71                21.19
# Other Operating Exp                               2.69                 2.79
# Total operating Exp                              21.40                23.98
# Profit before provisions & tax                   16.00                14.79
# Provision (Loans & contingencies)                10.33                 8.85
# Profit before tax                                 5.67                 5.94
#
#                                    2017-03-31 00:00:00  2018-03-31 00:00:00  \
# Income
# Interest Income                                 100.76               108.14
# Other Income                                     15.37                12.24
# Total Income                                    116.13               120.38
# Interest Exp                                     71.07                76.32
# Operating Exp                                    22.33                23.52
# Other Operating Exp                               3.38                 5.02
# Total operating Exp                              25.71                28.54
# Profit before provisions & tax                   19.35                15.52
# Provision (Loans & contingencies)                11.50                 8.32
# Profit before tax                                 7.85                 7.20
#
#                                    2019-03-31 00:00:00  2020-03-31 00:00:00  \
# Income
# Interest Income                                 115.65               120.20
# Other Income                                     12.55                19.00
# Total Income                                    128.20               139.20
# Interest Exp                                     82.74                82.44
# Operating Exp                                    24.08                27.14
# Other Operating Exp                               5.64                 7.40
# Total operating Exp                              29.72                34.54
# Profit before provisions & tax                   15.74                22.22
# Provision (Loans & contingencies)                 5.78                11.97
# Profit before tax                                 9.96                10.25
#
#                                    2021-03-31 00:00:00  2022-03-31 00:00:00  \
# Income
# Interest Income                                 128.60               140.03
# Other Income                                     16.43                22.13
# Total Income                                    145.03               162.16
# Interest Exp                                     86.51               101.85
# Operating Exp                                    28.76                29.84
# Other Operating Exp                               5.64                 6.41
# Total operating Exp                              34.40                36.25
# Profit before provisions & tax                   24.12                24.06
# Provision (Loans & contingencies)                12.09                 9.72
# Profit before tax                                12.03                14.34
#
#                                    2023-03-31 00:00:00  2024-03-31 00:00:00  \
# Income
# Interest Income                                 139.94               144.11
# Other Income                                     31.44                27.80
# Total Income                                    171.38               171.91
# Interest Exp                                    108.52               104.68
# Operating Exp                                    34.53                33.90
# Other Operating Exp                               6.65                12.67
# Total operating Exp                              41.18                46.57
# Profit before provisions & tax                   21.68                20.66
# Provision (Loans & contingencies)                 9.26                 7.86
# Profit before tax                                12.42                12.80
#
#                                    2025-03-31 00:00:00  2026-03-31 00:00:00  \
# Income
# Interest Income                                 159.86               193.78
# Other Income                                     28.54                20.78
# Total Income                                    188.40               214.56
# Interest Exp                                    109.37               144.26
# Operating Exp                                    42.35                39.44
# Other Operating Exp                               7.35                 4.91
# Total operating Exp                              49.70                44.35
# Profit before provisions & tax                   29.33                25.95
# Provision (Loans & contingencies)                15.79                 7.53
# Profit before tax                                13.54                18.42
#
#                                    % change
# Income
# Interest Income                       21.22
# Other Income                         -27.19
# Total Income                          13.89
# Interest Exp                          31.90
# Operating Exp                         -6.87
# Other Operating Exp                  -33.20
# Total operating Exp                  -10.76
# Profit before provisions & tax       -11.52
# Provision (Loans & contingencies)    -52.31
# Profit before tax                     36.04

# %%
# @title
# plottng YoY change in P&L Items

fig=plt.figure(figsize=(20,10))

c = ['red', 'blue', 'magenta', 'orange', 'brown', 'green', 'cyan']
bars = plt.bar(df7.index[np.abs(df7['% change']!=0)], df7['% change'][np.abs(df7['% change']!=0)], color = c)

# Add value labels
plt.bar_label(bars, fmt='%.1f%%', padding=5, fontsize=13)

plt.xticks(rotation = 90, fontsize = 20)
plt.axhline(-15, linestyle = 'dashed')
plt.axhline(15, linestyle = 'dashed')
plt.title(f'Movement of P&L Items as on {df7.columns[-2].date()}', fontsize = 20)
plt.xlabel('P&L item', fontsize = 20)
plt.ylabel('% change over prev year', fontsize = 20)

plt.show()

# %%
# @title
# Creating P&L variables for analysis

df7.drop(['% change'], axis =1, inplace = True)
sales= df7.loc['Total Income']

PBT= sales - df7.loc['Interest Exp']- df7.loc['Total operating Exp']- df7.loc['Provision (Loans & contingencies)']

total_assets = df2.loc['Cash + Balance with CB']+\
df2.loc['Balances with other Banks']+\
df2.loc['Balances with other Banks as FDR']+\
df2.loc['Securities bought under repo']+\
df2.loc['Investments (Amortised cost)']+df2.loc['Loans & Advances (Amortised cost)']+\
df2.loc['Interest Receivable']+\
df2.loc['Bills Purchased & Discounted']+\
df2.loc['Fixed Assets']+ df2.loc['Investment in properties'] + df2.loc['Other Assets']


capital= df2.loc['Capital']+ df2.loc['Reserve Fund']


# Calculating average total asset as sum of opening and closing total asset

avg_total_assets={}
for i in range(1,len(df2.columns)):
    avg_total_assets[df2.columns[i]]=round((total_assets[i-1]+total_assets[i])/2,2)


avg_total_assets=list(avg_total_assets.values())
avg_total_assets.insert(0,0)


avg_total_capital={}
for j in range(1,len(df2.columns)):
    avg_total_capital[df2.columns[j]]=round((capital[j-1]+capital[j])/2,2)


avg_total_capital=list(avg_total_capital.values())
avg_total_capital.insert(0,0)

# Calculating the Ratios as sum of opening and closing total asset

PBT_to_Sales = PBT/sales

sales_to_avg_total_asset= sales/avg_total_assets

avg_assets_to_capital={}
for i in range(1,len(avg_total_assets)):
    avg_assets_to_capital[df2.columns[i]]= avg_total_assets[i]/avg_total_capital[i]

avg_assets_to_capital=list(avg_assets_to_capital.values())
avg_assets_to_capital.insert(0,0)

# %%
# @title
data=np.array([sales,PBT,avg_total_assets,avg_total_capital])
A=pd.DataFrame(data, columns=col_ind, index=['Sales','PBT','Avg_Tot_Assets','Avg_Tot_Capital'])

# %%
# @title
A
# Out:
#                  2013-03-31  2014-03-31  2015-03-31  2016-03-31  2017-03-31  \
# Sales                 60.54       76.30       91.59      101.39      116.13
# PBT                    4.52        4.67        5.67        5.94        7.85
# Avg_Tot_Assets         0.00      757.64      876.42      917.21     1037.91
# Avg_Tot_Capital        0.00      105.09      109.50      113.83      118.02
#
#                  2018-03-31  2019-03-31  2020-03-31  2021-03-31  2022-03-31  \
# Sales                120.38      128.20      139.20      145.03      162.16
# PBT                    7.20        9.96       10.25       12.03       14.34
# Avg_Tot_Assets      1193.46     1333.53     1450.56     1488.20     1658.04
# Avg_Tot_Capital      123.28      130.43      140.60      153.52      191.83
#
#                  2023-03-31  2024-03-31  2025-03-31  2026-03-31
# Sales                171.38      171.91      188.40      214.56
# PBT                   12.42       12.80       13.54       18.42
# Avg_Tot_Assets      1910.30     2155.63     2349.03     2503.31
# Avg_Tot_Capital      231.70      243.38      266.79      287.18

# %%
# @title
ratio_data=np.array([PBT_to_Sales,sales_to_avg_total_asset,avg_assets_to_capital])

# %%
# @title
B=pd.DataFrame(ratio_data, columns=col_ind, index=['PBT/Income','Tot Income/Avg Assets','Avg Assets/Capital'])

# %%
# @title
C=B.iloc[:,1:len(B.columns)]

# %%
# @title
C
# Out:
#                        2014-03-31  2015-03-31  2016-03-31  2017-03-31  \
# PBT/Income               0.061206    0.061906    0.058586    0.067597
# Tot Income/Avg Assets    0.100707    0.104505    0.110542    0.111888
# Avg Assets/Capital       7.209440    8.003836    8.057718    8.794357
#
#                        2018-03-31  2019-03-31  2020-03-31  2021-03-31  \
# PBT/Income               0.059811    0.077691    0.073635    0.082948
# Tot Income/Avg Assets    0.100866    0.096136    0.095963    0.097453
# Avg Assets/Capital       9.680889   10.224105   10.316927    9.693851
#
#                        2022-03-31  2023-03-31  2024-03-31  2025-03-31  \
# PBT/Income               0.088431    0.072471    0.074458    0.071868
# Tot Income/Avg Assets    0.097802    0.089714    0.079749    0.080203
# Avg Assets/Capital       8.643278    8.244713    8.857055    8.804790
#
#                        2026-03-31
# PBT/Income               0.085850
# Tot Income/Avg Assets    0.085711
# Avg Assets/Capital       8.716867

# %% [markdown]
# ### 2.1 Return on Capital Employed (ROCE) Analysis

# %%
# @title
fig=plt.figure(figsize=(16,4))
fig.suptitle('Trend in ROCE Components', fontsize=15)

plt.subplot(1,3,1)
plt.plot(C.columns,C.iloc[0])
plt.title('Trend in Profit Margin (PBT/Tot Income)')
plt.xticks(rotation=45)

plt.subplot(1,3,2)
plt.plot(C.columns,C.iloc[1], color = 'brown')
plt.title('Trend in Tot Income/Avg Asset')
plt.xticks(rotation=45)

plt.subplot(1,3,3)
plt.plot(C.columns,C.iloc[2], color = 'green')
plt.title('Trend in Avg Asset/Capital')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### 2.2 Components of Profit Margin (PBT/Tot Income)

# %% [markdown]
# We further break PBT into sub-components to analyze the trend of the period:
#
#
#
# $$ \frac {PBT} {Tot Income} = \frac {Interest\ Income} {Tot Income} \ + \  \frac {Other\ Receipts} {Tot Income}  \ - \  \frac {Interest Paid} {Tot Income} - \  \frac {Operating \ Expense} {Tot Income} - \  \frac {Other\ Operating\ Expense} {Tot Income} - \  \frac {Provision} {Tot Income} $$

# %%
# @title
df7
# Out:
#                                    2013-03-31 00:00:00  2014-03-31 00:00:00  \
# Income
# Interest Income                                  54.23                67.48
# Other Income                                      6.31                 8.82
# Total Income                                     60.54                76.30
# Interest Exp                                     31.58                45.40
# Operating Exp                                    14.58                15.81
# Other Operating Exp                               2.42                 2.53
# Total operating Exp                              17.00                18.34
# Profit before provisions & tax                   11.96                12.56
# Provision (Loans & contingencies)                 7.44                 7.89
# Profit before tax                                 4.52                 4.67
#
#                                    2015-03-31 00:00:00  2016-03-31 00:00:00  \
# Income
# Interest Income                                  77.76                88.37
# Other Income                                     13.83                13.02
# Total Income                                     91.59               101.39
# Interest Exp                                     54.19                62.62
# Operating Exp                                    18.71                21.19
# Other Operating Exp                               2.69                 2.79
# Total operating Exp                              21.40                23.98
# Profit before provisions & tax                   16.00                14.79
# Provision (Loans & contingencies)                10.33                 8.85
# Profit before tax                                 5.67                 5.94
#
#                                    2017-03-31 00:00:00  2018-03-31 00:00:00  \
# Income
# Interest Income                                 100.76               108.14
# Other Income                                     15.37                12.24
# Total Income                                    116.13               120.38
# Interest Exp                                     71.07                76.32
# Operating Exp                                    22.33                23.52
# Other Operating Exp                               3.38                 5.02
# Total operating Exp                              25.71                28.54
# Profit before provisions & tax                   19.35                15.52
# Provision (Loans & contingencies)                11.50                 8.32
# Profit before tax                                 7.85                 7.20
#
#                                    2019-03-31 00:00:00  2020-03-31 00:00:00  \
# Income
# Interest Income                                 115.65               120.20
# Other Income                                     12.55                19.00
# Total Income                                    128.20               139.20
# Interest Exp                                     82.74                82.44
# Operating Exp                                    24.08                27.14
# Other Operating Exp                               5.64                 7.40
# Total operating Exp                              29.72                34.54
# Profit before provisions & tax                   15.74                22.22
# Provision (Loans & contingencies)                 5.78                11.97
# Profit before tax                                 9.96                10.25
#
#                                    2021-03-31 00:00:00  2022-03-31 00:00:00  \
# Income
# Interest Income                                 128.60               140.03
# Other Income                                     16.43                22.13
# Total Income                                    145.03               162.16
# Interest Exp                                     86.51               101.85
# Operating Exp                                    28.76                29.84
# Other Operating Exp                               5.64                 6.41
# Total operating Exp                              34.40                36.25
# Profit before provisions & tax                   24.12                24.06
# Provision (Loans & contingencies)                12.09                 9.72
# Profit before tax                                12.03                14.34
#
#                                    2023-03-31 00:00:00  2024-03-31 00:00:00  \
# Income
# Interest Income                                 139.94               144.11
# Other Income                                     31.44                27.80
# Total Income                                    171.38               171.91
# Interest Exp                                    108.52               104.68
# Operating Exp                                    34.53                33.90
# Other Operating Exp                               6.65                12.67
# Total operating Exp                              41.18                46.57
# Profit before provisions & tax                   21.68                20.66
# Provision (Loans & contingencies)                 9.26                 7.86
# Profit before tax                                12.42                12.80
#
#                                    2025-03-31 00:00:00  2026-03-31 00:00:00
# Income
# Interest Income                                 159.86               193.78
# Other Income                                     28.54                20.78
# Total Income                                    188.40               214.56
# Interest Exp                                    109.37               144.26
# Operating Exp                                    42.35                39.44
# Other Operating Exp                               7.35                 4.91
# Total operating Exp                              49.70                44.35
# Profit before provisions & tax                   29.33                25.95
# Provision (Loans & contingencies)                15.79                 7.53
# Profit before tax                                13.54                18.42

# %%
# @title
# Plotting the normalised P&L items

Int_Income = df7.loc['Interest Income']
Int_Income_to_sales=Int_Income/sales
#print(Int_Income_to_sales)



Oth_receipts = df7.loc['Other Income']
Oth_receipts_to_sales = Oth_receipts/sales
#print(Oth_receipts_to_sales)


Int_paid = df7.loc['Interest Exp']
Int_paid_to_sales = Int_paid/sales
#print(Int_paid_to_sales)



Op_exp=df7.loc['Operating Exp']
Op_exp_to_sales = Op_exp/sales
#print(Op_exp_to_sales)


Oth_op_exp=df7.loc['Other Operating Exp']
Oth_op_exp_to_sales=Oth_op_exp/sales
#print(Oth_op_exp_to_sales)


provision=df7.loc['Provision (Loans & contingencies)']
provision_to_sales=provision/sales
#print(provision_to_sales)

# %%
# @title
#Plotting trends in P&L Accounts

fig=plt.figure(figsize=(16,15))
fig.suptitle('Trend in PBT Components, % of Tot Income', fontsize=20)
fig.tight_layout(h_pad=10)

plt.subplot(3,2,1)
#plt.plot(data2.columns,data2.iloc[0], color = 'brown')
plt.plot(Int_Income_to_sales, color = 'brown')
plt.title('Trend in Interest & Discount')

plt.subplot(3,2,2)
plt.plot(Oth_receipts_to_sales, color = 'green')
plt.title('Trend in Oth Receipts')

plt.subplot(3,2,3)
plt.plot(Int_paid_to_sales, color = 'magenta')
plt.title('Trend in Interest Paid')

plt.subplot(3,2,4)
plt.plot(Op_exp_to_sales)
plt.title('Trend in Op Exp')

plt.subplot(3,2,5)
plt.plot(Oth_op_exp_to_sales, color = 'purple')
plt.title('Trend in Oth Op Exp')

plt.subplot(3,2,6)
plt.plot(provision_to_sales, color = 'olive')
plt.title('Trend in Provisios/Contingencies')

plt.show()

# %% [markdown]
# ## Business Model Analysis

# %% [markdown]
# ### BMA 1: Analysing business model through balance sheet evolution over the years

# %%
# Analysing balance sheet composition over the years

selected_items_asset = ["Cash + Balance with CB", "Balances with other Banks", "Balances with other Banks as FDR",
                        "Securities bought under repo", "Investments (Amortised cost)", "Investments (non-Amortised cost)",
                       "Loans & Advances (Amortised cost)", "Interest Receivable", "Bills Purchased & Discounted",
                       "Fixed Assets", "Investment in properties", "Other Assets"]



selected_items_liab = ["Capital", "Reserve Fund", "Other Reserve", "Deposits- Demand", "Deposits- Term",
                      "Borrowings- Interbank", "Borrowings- Repo", "Interest Payable ",
                       "Other Liabilities - Derivatives, Sub Debt etc.","Profit (Loss)",
                       "Current Tax Liabilities"]

# %%
# Movement of Assets over the years


# Normalize each column (year) so it sums to 1

df2_subset = df2.loc[selected_items_asset]

df_norm = df2_subset.div(df2_subset.sum(axis=0), axis=1)


# Transpose so years are on x-axis, items are stacked
ax = df_norm.T.plot(
    kind="bar",
    stacked=True,
    figsize=(12, 6),
    colormap="tab20"
)


# Add value labels inside each segment of every bar
for container in ax.containers:
    labels = [f"{v:.0%}" if v > 0.03 else "" for v in container.datavalues]
    ax.bar_label(container, labels=labels, label_type="center", fontsize=8, color="white")


ax.set_xlabel("Year")
ax.set_ylabel("Proportion of Total")
ax.set_title("Asset Composition by Year")
ax.legend(title="Item", bbox_to_anchor=(1.02, 1), loc="upper left")
ax.set_ylim(0, 1)

plt.tight_layout()
plt.show()

# %%
# Movement of liabilities over the years


# Normalize each column (year) so it sums to 1

df2_subset = df2.loc[selected_items_liab]

df_norm = df2_subset.div(df2_subset.sum(axis=0), axis=1)


# Transpose so years are on x-axis, items are stacked
ax = df_norm.T.plot(
    kind="bar",
    stacked=True,
    figsize=(12, 6),
    colormap="tab20"
)


# Add value labels inside each segment of every bar
for container in ax.containers:
    labels = [f"{v:.0%}" if v > 0.03 else "" for v in container.datavalues]
    ax.bar_label(container, labels=labels, label_type="center", fontsize=8, color="white")



ax.set_xlabel("Year")
ax.set_ylabel("Proportion of Total")
ax.set_title("Liability Composition by Year")
ax.legend(title="Item", bbox_to_anchor=(1.02, 1), loc="upper left")
ax.set_ylim(0, 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### BMA2: Balance sheet ratios for labeling type of business model
#
# i.	**Retail-funded**: it is characterised by a high share of loans on the balance sheet and high reliance on stable funding sources including deposits.
#
# ii.	**Wholesale-funded**:high share of loans on the balance sheet and high reliance on wholesale funding sources including deposits
#
# iii. **Trading bank**: More capital markets-oriented. Banks in this category hold half of their assets in the form of tradable securities and are predominately funded in wholesale markets. In fact, the average bank in this group is most active in the interbank market.

# %%
# First compute key ratios

bma_ratios = pd.DataFrame(index=df2.columns)
bma_ratios['loan_share'] = np.round(list(100*df2.loc["Loans & Advances (Amortised cost)"]/df2.loc["Total Assets"]),2)
bma_ratios['intbk_borrowing'] = np.round(list(100*df2.loc["Borrowings- Interbank"]/df2.loc["Total Assets"]),2)
bma_ratios['wholesale_debt'] = np.round(list(100*df2.loc["Deposits- Term"]/df2.loc["Total Assets"]),2)

# %%
bma_ratios
# Out:
#             loan_share  intbk_borrowing  wholesale_debt
# 2013-03-31       42.17             1.31           43.91
# 2014-03-31       41.28             1.48           47.65
# 2015-03-31       44.60             1.31           56.45
# 2016-03-31       48.64             0.57           60.99
# 2017-03-31       49.46             0.04           58.42
# 2018-03-31       51.97             0.01           60.42
# 2019-03-31       47.40             0.12           51.15
# 2020-03-31       57.59             0.16           57.62
# 2021-03-31       58.67             0.17           54.09
# 2022-03-31       53.44             0.17           64.02
# 2023-03-31       46.38             0.13           50.70
# 2024-03-31       47.55             0.16           55.85
# 2025-03-31       51.81             0.11           60.27
# 2026-03-31       52.73             0.05           50.26

# %%
# Plotting movement of key ratios over the years

bma_ratios.index = pd.to_datetime(bma_ratios.index)

fig, ax1 = plt.subplots(figsize=(10, 6))
ax2 = ax1.twinx()

# Bar plot on secondary axis
l2 = ax2.bar(
    bma_ratios.index, bma_ratios["intbk_borrowing"],
    width=150, color="tab:red", label="intbk_borrowing", zorder=1
)
ax2.set_ylabel("intbk_borrowing")
ax2.set_ylim(0, 10)

# Line plots on primary axis
l1, = ax1.plot(
    bma_ratios.index, bma_ratios["loan_share"],
    color="tab:blue", marker="o", label="loan_share", zorder=2
)
l3, = ax1.plot(
    bma_ratios.index, bma_ratios["wholesale_debt"],
    color="tab:green", marker="^", label="wholesale_debt", zorder=2
)
ax1.set_ylabel("loan_share / wholesale_debt")
ax1.set_xlabel("Date")


ax1.axhline(y=50, color="black", linestyle=":", linewidth=1)

# Combined legend
handles = [l1, l2, l3]
labels = [h.get_label() for h in handles]
ax1.legend(handles, labels, loc="upper right")

plt.title("Business Model Analysis Plot")
fig.tight_layout()
plt.show()
